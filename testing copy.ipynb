# %%
import pandas as pd

data = pd.read_json('data/bloomberg_quint_news.json')
data
# Out:
#                                                     url  \
# 0     https://www.bloombergquint.com/markets/all-you...
# 1     https://www.bloombergquint.com/business/bridge...
# 2     https://www.bloombergquint.com/markets/stocks-...
# 3     https://www.bloombergquint.com/research-report...
# 4     https://www.bloombergquint.com/business/cp-rai...
# ...                                                 ...
# 7013  https://www.bloombergquint.com/videos/2016/04/...
# 7014  https://www.bloombergquint.com/videos/2016/04/...
# 7015  https://www.bloombergquint.com/videos/2016/04/...
# 7016  https://www.bloombergquint.com/videos/2016/04/...
# 7017  https://www.bloombergquint.com/videos/2016/04/...
#
#                                                   title  \
# 0     All You Need To Know Going Into Trade On Septe...
# 1     Bridgestone CEO Backs Safe Tokyo Olympics, Dia...
# 2     Stocks To Watch: HCL Tech, Cyient, M&M Financi...
# 3     Localised Lockdowns Cannot But Impinge On Econ...
# 4     CP Rail Wins Regulator Exemption From Tougher ...
# ...                                                 ...
# 7013           What's Behind Canada's Employment Surge?
# 7014             Weeks of Ups and Downs for the S&P 500
# 7015  Inside the Lowered Expectations for Corporate ...
# 7016                 Who Will Be Peru’s Next President?
# 7017                    Wrapping Up the Week in Markets
#
#                                       short_description  \
# 0     Stocks in the news, big brokerage calls of the...
# 1     Bridgestone CEO Backs Safe Tokyo Olympics, Dia...
# 2        Here are the stocks to watch in trade today...
# 3     Localised Lockdowns Cannot But Impinge On Econ...
# 4     CP Rail Wins Regulator Exemption From Tougher ...
# ...                                                 ...
# 7013           What's Behind Canada's Employment Surge?
# 7014             Weeks of Ups and Downs for the S&P 500
# 7015  Inside the Lowered Expectations for Corporate ...
# 7016                 Who Will Be Peru’s Next President?
# 7017                    Wrapping Up the Week in Markets
#
#                                   author              date_created  \
# 0                       Darshan A Nakhwa  23 Sep 2021, 7:05 AM IST
# 1                       Shiho Takezawa &  23 Apr 2021, 5:35 AM IST
# 2                                BQ Desk  23 Apr 2021, 7:29 AM IST
# 3     Nirmal Bang Institutional Research  26 Apr 2021, 7:58 AM IST
# 4                           Thomas Black  24 Apr 2021, 7:08 AM IST
# ...                                  ...                       ...
# 7013                                None                      None
# 7014                                None                      None
# 7015                                None                      None
# 7016                                None                      None
# 7017                                None                      None
#
#                  date_modified          category  \
# 0     23 Sep 2021, 7:05 AM IST           Markets
# 1     23 Apr 2021, 6:35 AM IST          Business
# 2     23 Apr 2021, 7:29 AM IST           Markets
# 3     26 Apr 2021, 7:58 AM IST  Research Reports
# 4     24 Apr 2021, 7:44 AM IST          Business
# ...                        ...               ...
# 7013                      None            Videos
# 7014                      None            Videos
# 7015                      None            Videos
# 7016                      None            Videos
# 7017                      None            Videos
#
#                                         raw_description  \
# 0     <div class="story-element story-element-text">...
# 1     <div class="story-element story-element-text">...
# 2     <div class="story-element story-element-text">...
# 3     <div class="story-element story-element-text">...
# 4     <div class="story-element story-element-text">...
# ...                                                 ...
# 7013  <div class="story-element story-element-text">...
# 7014  <div class="story-element story-element-text">...
# 7015  <div class="story-element story-element-text">...
# 7016  <div class="story-element story-element-text">...
# 7017  <div class="story-element story-element-text">...
#
#                                             description  \
# 0     Asian stocks were steady early Thursday after ...
# 1      Bridgestone Corp. will support the Tokyo Olym...
# 2     Indian equity benchmarks reversed losses made ...
# 3     Nirmal Bang Report, We assess the ‘state of af...
# 4      Canadian Pacific Railway Ltd. won a petition ...
# ...                                                 ...
# 7013
# 7014
# 7015
# 7016
# 7017
#
#                             publisher          scraped_at
# 0     https://www.bloombergquint.com/ 2021-09-24 00:01:25
# 1     https://www.bloombergquint.com/ 2021-09-24 00:01:26
# 2     https://www.bloombergquint.com/ 2021-09-24 00:01:26
# 3     https://www.bloombergquint.com/ 2021-09-24 00:01:26
# 4     https://www.bloombergquint.com/ 2021-09-24 00:01:27
# ...                               ...                 ...
# 7013  https://www.bloombergquint.com/ 2021-09-24 01:22:29
# 7014  https://www.bloombergquint.com/ 2021-09-24 01:22:29
# 7015  https://www.bloombergquint.com/ 2021-09-24 01:22:29
# 7016  https://www.bloombergquint.com/ 2021-09-24 01:22:30
# 7017  https://www.bloombergquint.com/ 2021-09-24 01:22:30
#
# [7018 rows x 11 columns]

# %%
def check_missing_values(df):
    # Check for NaN, missing, or NaT values
    missing_rows = df[df.isnull().any(axis=1)]

    if not missing_rows.empty:
        print("Deleting rows with missing values...")
        df.dropna(inplace=True)
        print("Rows with missing values have been deleted.")
    else:
        print("There are no missing values in the DataFrame.")

# Example usage:
check_missing_values(data)
data
# Out:
# Deleting rows with missing values...
# Rows with missing values have been deleted.
#                                                     url  \
# 0     https://www.bloombergquint.com/markets/all-you...
# 1     https://www.bloombergquint.com/business/bridge...
# 2     https://www.bloombergquint.com/markets/stocks-...
# 3     https://www.bloombergquint.com/research-report...
# 4     https://www.bloombergquint.com/business/cp-rai...
# ...                                                 ...
# 5985  https://www.bloombergquint.com/opinion/2015/10...
# 6286  https://www.bloombergquint.com/opinion/2015/12...
# 6433  https://www.bloombergquint.com/opinion/2015/12...
# 6513  https://www.bloombergquint.com/politics/2016/0...
# 6660  https://www.bloombergquint.com/technology/2016...
#
#                                                   title  \
# 0     All You Need To Know Going Into Trade On Septe...
# 1     Bridgestone CEO Backs Safe Tokyo Olympics, Dia...
# 2     Stocks To Watch: HCL Tech, Cyient, M&M Financi...
# 3     Localised Lockdowns Cannot But Impinge On Econ...
# 4     CP Rail Wins Regulator Exemption From Tougher ...
# ...                                                 ...
# 5985  Why Is India Dragging Its Feet on the Uniform ...
# 6286  45 Years of Liberation, Is B’desh Still Insuff...
# 6433      Remembering Raj Kapoor, a Man Who Wept Easily
# 6513  Parkash Singh Badal and the ‘Secret File’ on P...
# 6660  Modular LG G5  With Dual Camera & Swap Out Bat...
#
#                                       short_description  \
# 0     Stocks in the news, big brokerage calls of the...
# 1     Bridgestone CEO Backs Safe Tokyo Olympics, Dia...
# 2        Here are the stocks to watch in trade today...
# 3     Localised Lockdowns Cannot But Impinge On Econ...
# 4     CP Rail Wins Regulator Exemption From Tougher ...
# ...                                                 ...
# 5985  The Supreme Court’s advice has major implicati...
# 6286  \n\nB’desh is still a young nation which adher...
# 6433  Khalid Mohamed shares a glimpse from the life ...
# 6513  A list naming Punjab’s drug lords & politician...
# 6660  The ability to add an extra layer of battery o...
#
#                                   author              date_created  \
# 0                       Darshan A Nakhwa  23 Sep 2021, 7:05 AM IST
# 1                       Shiho Takezawa &  23 Apr 2021, 5:35 AM IST
# 2                                BQ Desk  23 Apr 2021, 7:29 AM IST
# 3     Nirmal Bang Institutional Research  26 Apr 2021, 7:58 AM IST
# 4                           Thomas Black  24 Apr 2021, 7:08 AM IST
# ...                                  ...                       ...
# 5985                     Mohan Guruswamy  15 Oct 2015, 5:01 AM IST
# 6286                       Chandan Nandy  16 Dec 2015, 4:09 AM IST
# 6433                      Khalid Mohamed  14 Dec 2015, 3:09 PM IST
# 6513                         Shashi Kant  12 Jan 2016, 2:28 PM IST
# 6660                          S Aadeetya  22 Feb 2016, 2:19 PM IST
#
#                   date_modified          category  \
# 0      23 Sep 2021, 7:05 AM IST           Markets
# 1      23 Apr 2021, 6:35 AM IST          Business
# 2      23 Apr 2021, 7:29 AM IST           Markets
# 3      26 Apr 2021, 7:58 AM IST  Research Reports
# 4      24 Apr 2021, 7:44 AM IST          Business
# ...                         ...               ...
# 5985   01 Jul 2016, 6:30 PM IST           Opinion
# 6286  02 Jul 2016, 10:47 AM IST           Opinion
# 6433   02 Jun 2016, 5:28 PM IST           Opinion
# 6513  18 Jun 2016, 11:14 AM IST          Politics
# 6660   01 Jun 2016, 2:35 PM IST        Technology
#
#                                         raw_description  \
# 0     <div class="story-element story-element-text">...
# 1     <div class="story-element story-element-text">...
# 2     <div class="story-element story-element-text">...
# 3     <div class="story-element story-element-text">...
# 4     <div class="story-element story-element-text">...
# ...                                                 ...
# 5985  <div class="story-element story-element-text">...
# 6286  <div class="story-element story-element-text">...
# 6433  <div class="story-element story-element-text">...
# 6513  <div class="story-element story-element-text">...
# 6660  <div class="story-element story-element-text">...
#
#                                             description  \
# 0     Asian stocks were steady early Thursday after ...
# 1      Bridgestone Corp. will support the Tokyo Olym...
# 2     Indian equity benchmarks reversed losses made ...
# 3     Nirmal Bang Report, We assess the ‘state of af...
# 4      Canadian Pacific Railway Ltd. won a petition ...
# ...                                                 ...
# 5985  The Supreme Court on Monday gave the governmen...
# 6286  \n\n, Like Salman Rushdie’s portrayal of Pakis...
# 6433  My reason for writing today is to illustrate t...
# 6513  It was an autumn afternoon in 2007 when I step...
# 6660  LG has finally made it to the flagship smartph...
#
#                             publisher          scraped_at
# 0     https://www.bloombergquint.com/ 2021-09-24 00:01:25
# 1     https://www.bloombergquint.com/ 2021-09-24 00:01:26
# 2     https://www.bloombergquint.com/ 2021-09-24 00:01:26
# 3     https://www.bloombergquint.com/ 2021-09-24 00:01:26
# 4     https://www.bloombergquint.com/ 2021-09-24 00:01:27
# ...                               ...                 ...
# 5985  https://www.bloombergquint.com/ 2021-09-24 00:32:24
# 6286  https://www.bloombergquint.com/ 2021-09-24 00:33:21
# 6433  https://www.bloombergquint.com/ 2021-09-24 00:33:47
# 6513  https://www.bloombergquint.com/ 2021-09-24 00:34:02
# 6660  https://www.bloombergquint.com/ 2021-09-24 00:34:28
#
# [4106 rows x 11 columns]

# %%
import re
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

def _removeNonAscii(s):
    return "".join(i for i in s if  ord(i)<128)

def make_lower_case(text):
    return text.lower()

def remove_stop_words(text):
    text = text.split()
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops]
    text = " ".join(text)
    return text

def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

def remove_punctuation(text):
    tokenizer = RegexpTokenizer(r'\w+')
    text = tokenizer.tokenize(text)
    text = " ".join(text)
    return text

# call the functions and clean the text for the title, short_description, and description columns
data['title'] = data['title'].apply(_removeNonAscii)
data['title'] = data['title'].apply(make_lower_case)
data['title'] = data['title'].apply(remove_stop_words)
data['title'] = data['title'].apply(remove_punctuation)
data['title'] = data['title'].apply(remove_html)

data['short_description'] = data['short_description'].apply(_removeNonAscii)
data['short_description'] = data['short_description'].apply(make_lower_case)
data['short_description'] = data['short_description'].apply(remove_stop_words)
data['short_description'] = data['short_description'].apply(remove_punctuation)
data['short_description'] = data['short_description'].apply(remove_html)

data['description'] = data['description'].apply(_removeNonAscii)
data['description'] = data['description'].apply(make_lower_case)
data['description'] = data['description'].apply(remove_stop_words)
data['description'] = data['description'].apply(remove_punctuation)
data['description'] = data['description'].apply(remove_html)

data
# Out:
#                                                     url  \
# 0     https://www.bloombergquint.com/markets/all-you...
# 1     https://www.bloombergquint.com/business/bridge...
# 2     https://www.bloombergquint.com/markets/stocks-...
# 3     https://www.bloombergquint.com/research-report...
# 4     https://www.bloombergquint.com/business/cp-rai...
# ...                                                 ...
# 5985  https://www.bloombergquint.com/opinion/2015/10...
# 6286  https://www.bloombergquint.com/opinion/2015/12...
# 6433  https://www.bloombergquint.com/opinion/2015/12...
# 6513  https://www.bloombergquint.com/politics/2016/0...
# 6660  https://www.bloombergquint.com/technology/2016...
#
#                                                   title  \
# 0                    need know going trade september 23
# 1     bridgestone ceo backs safe tokyo olympics dial...
# 2     stocks watch hcl tech cyient m m financial ser...
# 3     localised lockdowns cannot impinge economic ac...
# 4     cp rail wins regulator exemption tougher 2001 ...
# ...                                                 ...
# 5985             india dragging feet uniform civil code
# 6286  45 years liberation bdesh still insufficiently...
# 6433             remembering raj kapoor man wept easily
# 6513  parkash singh badal secret file punjabs drug b...
# 6660       modular lg g5 dual camera swap battery india
#
#                                       short_description  \
# 0     stocks news big brokerage calls day complete t...
# 1     bridgestone ceo backs safe tokyo olympics dial...
# 2                              stocks watch trade today
# 3     localised lockdowns cannot impinge economic ac...
# 4     cp rail wins regulator exemption tougher 2001 ...
# ...                                                 ...
# 5985  supreme courts advice major implications india...
# 6286  bdesh still young nation adheres rituals vener...
# 6433  khalid mohamed shares glimpse life raj kapoor ...
# 6513  list naming punjabs drug lords politicians inv...
# 6660  ability add extra layer battery even add camer...
#
#                                   author              date_created  \
# 0                       Darshan A Nakhwa  23 Sep 2021, 7:05 AM IST
# 1                       Shiho Takezawa &  23 Apr 2021, 5:35 AM IST
# 2                                BQ Desk  23 Apr 2021, 7:29 AM IST
# 3     Nirmal Bang Institutional Research  26 Apr 2021, 7:58 AM IST
# 4                           Thomas Black  24 Apr 2021, 7:08 AM IST
# ...                                  ...                       ...
# 5985                     Mohan Guruswamy  15 Oct 2015, 5:01 AM IST
# 6286                       Chandan Nandy  16 Dec 2015, 4:09 AM IST
# 6433                      Khalid Mohamed  14 Dec 2015, 3:09 PM IST
# 6513                         Shashi Kant  12 Jan 2016, 2:28 PM IST
# 6660                          S Aadeetya  22 Feb 2016, 2:19 PM IST
#
#                   date_modified          category  \
# 0      23 Sep 2021, 7:05 AM IST           Markets
# 1      23 Apr 2021, 6:35 AM IST          Business
# 2      23 Apr 2021, 7:29 AM IST           Markets
# 3      26 Apr 2021, 7:58 AM IST  Research Reports
# 4      24 Apr 2021, 7:44 AM IST          Business
# ...                         ...               ...
# 5985   01 Jul 2016, 6:30 PM IST           Opinion
# 6286  02 Jul 2016, 10:47 AM IST           Opinion
# 6433   02 Jun 2016, 5:28 PM IST           Opinion
# 6513  18 Jun 2016, 11:14 AM IST          Politics
# 6660   01 Jun 2016, 2:35 PM IST        Technology
#
#                                         raw_description  \
# 0     <div class="story-element story-element-text">...
# 1     <div class="story-element story-element-text">...
# 2     <div class="story-element story-element-text">...
# 3     <div class="story-element story-element-text">...
# 4     <div class="story-element story-element-text">...
# ...                                                 ...
# 5985  <div class="story-element story-element-text">...
# 6286  <div class="story-element story-element-text">...
# 6433  <div class="story-element story-element-text">...
# 6513  <div class="story-element story-element-text">...
# 6660  <div class="story-element story-element-text">...
#
#                                             description  \
# 0     asian stocks steady early thursday u s shares ...
# 1     bridgestone corp support tokyo olympics paraly...
# 2     indian equity benchmarks reversed losses made ...
# 3     nirmal bang report assess state affairs string...
# 4     canadian pacific railway ltd petition proposed...
# ...                                                 ...
# 5985  supreme court monday gave government three wee...
# 6286  like salman rushdies portrayal pakistan shame ...
# 6433  reason writing today illustrate man filmmaker ...
# 6513  autumn afternoon 2007 stepped chandigarhs sect...
# 6660  lg finally made flagship smartphone space indi...
#
#                             publisher          scraped_at
# 0     https://www.bloombergquint.com/ 2021-09-24 00:01:25
# 1     https://www.bloombergquint.com/ 2021-09-24 00:01:26
# 2     https://www.bloombergquint.com/ 2021-09-24 00:01:26
# 3     https://www.bloombergquint.com/ 2021-09-24 00:01:26
# 4     https://www.bloombergquint.com/ 2021-09-24 00:01:27
# ...                               ...                 ...
# 5985  https://www.bloombergquint.com/ 2021-09-24 00:32:24
# 6286  https://www.bloombergquint.com/ 2021-09-24 00:33:21
# 6433  https://www.bloombergquint.com/ 2021-09-24 00:33:47
# 6513  https://www.bloombergquint.com/ 2021-09-24 00:34:02
# 6660  https://www.bloombergquint.com/ 2021-09-24 00:34:28
#
# [4106 rows x 11 columns]

# %%
corpus_title = data['title'].tolist()
corpus_short_description = data['short_description'].tolist()
corpus_description = data['description'].tolist()

def get_corpus(text):
    words = []
    for i in text:
        text = [word for word in i.split()]
        words.append(text)
    return words

corpus_title = get_corpus(corpus_title)
corpus_short_description = get_corpus(corpus_short_description)
corpus_description = get_corpus(corpus_description)

corpus_title
# Out:
# [['need', 'know', 'going', 'trade', 'september', '23'],
#  ['bridgestone',
#   'ceo',
#   'backs',
#   'safe',
#   'tokyo',
#   'olympics',
#   'dials',
#   'back',
#   'marketing'],
#  ['stocks',
#   'watch',
#   'hcl',
#   'tech',
#   'cyient',
#   'm',
#   'm',
#   'financial',
#   'services',
#   'tata',
#   'motors',
#   'torrent',
#   'power',
#   'wipro'],
#  ['localised',
#   'lockdowns',
#   'cannot',
#   'impinge',
#   'economic',
#   'activity',
#   'nirmal',
#   'bang'],
#  ['cp',
#   'rail',
#   'wins',
#   'regulator',
#   'exemption',
#   'tougher',
#   '2001',
#   'merger',
#   'rules'],
#  ['uber',
#   'lyft',
#   'spending',
#   'millions',
#   'driver',
#   'bonuses',
#   'end',
#   'shortage'],
#  ['stocks',
#   'watch',
#   'axis',
#   'bank',
#   'bajaj',
#   'finance',
#   'info',
#   'edge',
#   'britannia',
#   'united',
#   'breweries'],
#  ['japan',
#   'approve',
#   'moderna',
#   'vaccine',
#   'soon',
#   'may',
#   '21',
#   'yomiuri',
#   'says'],
#  ['russia', 'navalny', '2', '0'],
#  ['need', 'know', 'going', 'trade', 'april', '28'],
#  ['mutual',
#   'fund',
#   'show',
#   'investors',
#   'need',
#   'global',
#   'equity',
#   'exposure'],
#  ['hard', 'take', 'dogecoinseriously', 'doge', 'doesnt', 'care'],
#  ['australias', 'budget', 'include', 'a', '1', '7', 'billion', 'childcare'],
#  ['lenders', 'stepped', 'auctions', 'gold', 'jewellery'],
#  ['thinkpad', 'keeping', 'lights'],
#  ['philippines',
#   'clears',
#   'moderna',
#   'covid',
#   '19',
#   'vaccine',
#   'emergency',
#   'use'],
#  ['worlds',
#   'first',
#   'electric',
#   'station',
#   'wagon',
#   'porsche',
#   'delivers',
#   'utility'],
#  ['need', 'know', 'going', 'trade', 'may', '4'],
#  ['need', 'know', 'going', 'trade', 'may', '5'],
#  ['rupee', 'bond', 'update', 'may', '05', '2021', 'reliance', 'securities'],
#  ['mclarens', 'new', 'convertible', 'exception', 'racings', 'oldest', 'rule'],
#  ['bqedge', 'keep', 'eye', 'infosys', 'stock'],
#  ['need', 'know', 'going', 'trade', 'feb', '20'],
#  ['stocks',
#   'radar',
#   'yes',
#   'bank',
#   'dixon',
#   'technologies',
#   'majesco',
#   'dr',
#   'reddys',
#   'labs'],
#  ['football', 'fans', 'poland', 'raise', '1', 'million', 'ailing', 'team'],
#  ['spies',
#   'satellites',
#   'analyzing',
#   'north',
#   'korea',
#   's',
#   'economy',
#   'isnt',
#   'easy'],
#  ['putin',
#   'sees',
#   'russia',
#   'investment',
#   'boom',
#   'equity',
#   'analysts',
#   'dont'],
#  ['brussels', 'edition', 'significant', 'significant'],
#  ['brexit',
#   'era',
#   'trade',
#   'south',
#   'africa',
#   'budget',
#   'japan',
#   's',
#   'exports',
#   'eco',
#   'day'],
#  ['growth', 'glum', 'rate', 'cut', 'come', 'says', 'nomura'],
#  ['china',
#   'biotech',
#   'stock',
#   'soars',
#   'tipping',
#   '245',
#   'percent',
#   'profit',
#   'jump'],
#  ['middle', 'class', 'india', 'today'],
#  ['e',
#   'commerce',
#   'policy',
#   'changes',
#   'shaken',
#   'confidence',
#   'india',
#   'says',
#   'walmart'],
#  ['britain',
#   'bans',
#   'drones',
#   'flying',
#   'within',
#   '5',
#   'kilometers',
#   'airports'],
#  ['33rd',
#   'gst',
#   'council',
#   'meeting',
#   'live',
#   'arun',
#   'jaitley',
#   'adjourns',
#   'meeting',
#   'feb',
#   '24'],
#  ['emaar', 'denies', 'reports', 'accept', 'payment', 'digital', 'currency'],
#  ['indication',
#   'world',
#   'cup',
#   'matches',
#   'wont',
#   'go',
#   'ahead',
#   'icc',
#   'ceo'],
#  ['ambuja', 'cements', 'lagged', 'peers', 'last', 'quarter'],
#  ['foreign', 'direct', 'investment', 'falls', '7', 'april', 'december'],
#  ['jsw',
#   'cement',
#   'plans',
#   'increase',
#   'capacity',
#   '6',
#   'million',
#   'tonnes',
#   'two',
#   'years'],
#  ['brexit', 'bulletin', 'last', 'chance', 'saloon'],
#  ['pulwama', 'avoiding', 'tactical', 'trap'],
#  ['eskoms', 'cash', 'needs', 'could', 'strain', 'south', 'africas', 'budget'],
#  ['nasscom',
#   'wont',
#   'provide',
#   'fy20',
#   'guidance',
#   'releases',
#   'ceo',
#   'survey',
#   'instead'],
#  ['cathay', 'pacific', 'sees', 'end', 'record', 'run', 'losses', 'revamp'],
#  ['saudi',
#   'aramco',
#   'talks',
#   'ril',
#   'joint',
#   'investment',
#   'petchem',
#   'refinery',
#   'projects'],
#  ['pound', 'traders', 'stop', 'obsessing', 'overbrexit', 'day'],
#  ['enforcement',
#   'directorate',
#   'raids',
#   'multiple',
#   'locations',
#   'linked',
#   'il',
#   'fs',
#   'crisis'],
#  ['sanders',
#   'tops',
#   '2020',
#   'democrats',
#   '4',
#   'million',
#   'day',
#   'one',
#   'haul'],
#  ['q3',
#   'review',
#   'indian',
#   'automakers',
#   'struggle',
#   'rev',
#   'growth',
#   'engines'],
#  ['sensex', 'halts', 'worst', 'losing', 'streak', 'since', '2011'],
#  ['curious',
#   'case',
#   'deadly',
#   'pig',
#   'virus',
#   'remote',
#   'vietnamese',
#   'farms'],
#  ['china',
#   's',
#   'yuan',
#   'rally',
#   'seen',
#   'short',
#   'lived',
#   'despite',
#   'trade',
#   'optimism'],
#  ['donald',
#   'trump',
#   's',
#   '25',
#   'billion',
#   'problem',
#   'germany',
#   's',
#   'carmakers'],
#  ['trump',
#   'poised',
#   'name',
#   'jeffrey',
#   'rosen',
#   'deputy',
#   'attorney',
#   'general'],
#  ['thai', 'stock', 'forecast', 'surge', '49', 'withina', 'year'],
#  ['zero',
#   'loses',
#   'magic',
#   'world',
#   's',
#   'biggest',
#   'covered',
#   'bond',
#   'market'],
#  ['airbus',
#   'optimistic',
#   'indian',
#   'air',
#   'forces',
#   'transport',
#   'plane',
#   'order'],
#  ['philippinespermanently',
#   'bans',
#   'dengue',
#   'vaccine',
#   'set',
#   'health',
#   'scare'],
#  ['zambia',
#   'court',
#   'orders',
#   'liquidation',
#   'billionaire',
#   'levievs',
#   'company'],
#  ['lloyds',
#   'pushes',
#   'ahead',
#   '2',
#   '3',
#   'billion',
#   'buyback',
#   'amid',
#   'u',
#   'k',
#   'turmoil'],
#  ['south',
#   'africa',
#   'cut',
#   'wage',
#   'bill',
#   'help',
#   'fund',
#   'power',
#   'utility',
#   'bailout'],
#  ['budget', 'gives', 'rand', 'traders', 'shakes', 'anc', 'conference'],
#  ['security', 'becomes', 'muddy', 'battleground', 'israel', 's', 'election'],
#  ['woolworths', 'ceo', 'moir', 'pressure', 'australian', 'dream', 'fades'],
#  ['oyo', 'expands', 'international', 'footprint', 'saudi', 'arabia', 'foray'],
#  ['hong',
#   'kong',
#   'take',
#   'back',
#   'part',
#   'biggest',
#   'golf',
#   'course',
#   'homes'],
#  ['guaido', 'amnesty', 'venezuelan', 'army', 'stalls', 'legislature'],
#  ['deutsche', 'bank', 'plans', 'rebuild', 'south', 'africa', 'staff', 'cuts'],
#  ['highlights', 'south', 'africa', 's', '2019', 'annual', 'budget'],
#  ['finalists', 'world', 'car', 'year', 'award', '2019'],
#  ['manchester',
#   'city',
#   'owner',
#   'adds',
#   'chinese',
#   'team',
#   'growing',
#   'soccer',
#   'empire'],
#  ['bad', 'banks', 'really', 'hurt', 'economy'],
#  ['bernie', 's', 'back', 'trump', 'may', 'fine'],
#  ['ex', 'goldman', 'ng', 'extradition', 'delayed', 'malaysia', 'cases'],
#  ['five', 'things', 'need', 'know', 'start', 'day'],
#  ['tycoon',
#   'richard',
#   'li',
#   's',
#   'fwd',
#   'hires',
#   'ex',
#   'deutsche',
#   'bank',
#   'dealmaker',
#   'm',
#   'a'],
#  ['moodys',
#   'upgrades',
#   'tata',
#   'steels',
#   'corporate',
#   'family',
#   'rating',
#   'ba2'],
#  ['fed',
#   'minutes',
#   'u',
#   's',
#   's',
#   'yuan',
#   'demand',
#   'brazil',
#   'pension',
#   'plan',
#   'eco',
#   'day'],
#  ['southafrica',
#   'budgets',
#   'land',
#   'purchases',
#   'even',
#   'expropriation',
#   'looms'],
#  ['aclu', 'sues', 'trump', 'border', 'wall', 'emergency', 'lawsuits', 'pile'],
#  ['ubs', 'hit', 'record', 'penalty', 'money', 'laundering', 'conviction'],
#  ['british', 'banks', 'getting', 'last', 'minute', 'break', 'eu'],
#  ['airbus',
#   'says',
#   'engine',
#   'issues',
#   'resolved',
#   'aims',
#   'speed',
#   'india',
#   'deliveries'],
#  ['sainsbury', 'walk', 'away', 'asda', 'deal'],
#  ['bquick', 'feb', '20', 'top', '10', 'stories', '10', 'minutes'],
#  ['eurofins',
#   'scientific',
#   'board',
#   'independence',
#   'could',
#   'enhanced',
#   'report',
#   'says'],
#  ['gst',
#   'council',
#   'defers',
#   'decision',
#   'tax',
#   'cut',
#   'proposal',
#   'real',
#   'estate',
#   'sector'],
#  ['stocks', 'likely', 'exit', 'enter', 'nifty', '50'],
#  ['tiny', 'gulf', 'nation', 'opening', 'doors', 'crypto'],
#  ['trump', 'tariff', 'threat', 'leaves', 'eu', 'looking', 'plan', 'b'],
#  ['kenya',
#   'lake',
#   'region',
#   'counties',
#   'bloc',
#   'mulls',
#   'buying',
#   'consolidated',
#   'bank'],
#  ['regulatory',
#   'cost',
#   'weighs',
#   'india',
#   's',
#   'ceos',
#   'modi',
#   'fights',
#   'corruption'],
#  ['washington', 'boston', 'beating', 'nyc', 'entrepreneurial', 'talent'],
#  ['india',
#   'inject',
#   '6',
#   '8',
#   'billion',
#   'state',
#   'lenders',
#   'boost',
#   'loans'],
#  ['domestic', 'air', 'passenger', 'traffic', 'rises', '9', '1', 'january'],
#  ['china', 'probes', 'local', 'firm', 'trading', 'losses', 'hit', 'citi'],
#  ['topgolf', 'seeks', 'piece', 'sport', 'betting', 'deal', 'online', 'casino'],
#  ['turkey',
#   'unhappy',
#   'u',
#   's',
#   'missile',
#   'offer',
#   'russia',
#   'readies',
#   's',
#   '400s'],
#  ['saudi',
#   'crown',
#   'prince',
#   'sees',
#   '100',
#   'billion',
#   'investment',
#   'opportunity',
#   'india'],
#  ['pound',
#   'declines',
#   'u',
#   'k',
#   's',
#   'may',
#   'suffers',
#   'another',
#   'political',
#   'setback'],
#  ['europe', 'sees', 'possible', 'green', 'shoots', 'confidence', 'rises'],
#  ['sainsbury',
#   'andasda',
#   'opposed',
#   'selling',
#   'either',
#   'brand',
#   'save',
#   '9',
#   '5',
#   'billion',
#   'deal'],
#  ['brexit',
#   'dulls',
#   'u',
#   'k',
#   'oil',
#   's',
#   'allure',
#   'korean',
#   'buyer',
#   'flags',
#   'trade',
#   'risks'],
#  ['ratnagiri', 'refinery', 'commissioned', '2025', 'ceo', 'says'],
#  ['cong',
#   'seals',
#   'alliance',
#   'dmk',
#   'contest',
#   '9',
#   'seats',
#   'tamil',
#   'nadu'],
#  ['sainsbury', 'asda', 'deal', 'may', 'doomed', 'antitrust', 'report'],
#  ['somedayyour', 'self', 'driving', 'car', 'pull', 'police'],
#  ['iraq', 'says', 'continue', 'sanctions', 'busting', 'imports', 'iran'],
#  ['china',
#   'iron',
#   'ore',
#   'demand',
#   'could',
#   'keep',
#   'payouts',
#   'coming',
#   'fortescue',
#   'says'],
#  ['ramaphosa', 'sets', 'battle', 'unions', 'eskom', 'ahead', 'election'],
#  ['dassault', 'ceo', 'defends', 'role', 'reliance', 'rafale', 'deal'],
#  ['south',
#   'africa',
#   's',
#   'worsening',
#   'economic',
#   'fiscal',
#   'outlook',
#   'charts'],
#  ['trump', 'meet', 'millennial', 'challenged', 'merkel', 'refugees'],
#  ['wall',
#   'street',
#   'hawk',
#   'found',
#   'bloodied',
#   'ahead',
#   'fomc',
#   'taking',
#   'stock'],
#  ['chinas', 'recession', 'proof', 'economy', 'heads', 'stresstest'],
#  ['top',
#   'ethics',
#   'watchdog',
#   'rejects',
#   'ross',
#   's',
#   'financial',
#   'disclosure',
#   'form'],
#  ['praet', 'hits', 'back', 'sirens', 'ecb', 'odyssey', 'forward', 'guidance'],
#  ['private', 'equity', 'could', 'surprise', 'guest', 'tv', 'drama'],
#  ['ubs',
#   'ordered',
#   'pay',
#   'record',
#   '5',
#   '1',
#   'billion',
#   'french',
#   'tax',
#   'fraud',
#   'trial'],
#  ['msci',
#   'spooks',
#   'argentine',
#   'investors',
#   'statement',
#   'onindex',
#   'placements'],
#  ['bernie',
#   'sanders',
#   'draws',
#   'record',
#   '5',
#   '9',
#   'million',
#   'one',
#   'day',
#   'starts',
#   '2020',
#   'run'],
#  ['lendingclub',
#   'slides',
#   'view',
#   'miss',
#   'credit',
#   'fears',
#   'worry',
#   'analysts'],
#  ['top', 'investor', 'jail', 'putin', 'hits', 'business', 'climate'],
#  ['paying', 'tax', 'beats', 'paying', 'dividend'],
#  ['brazil', 'unveils', 'details', 'bold', '312', 'billion', 'pension', 'plan'],
#  ['syria', 'says', 'u', 's', 'allies', 'help', 'reconstruction'],
#  ['swedens',
#   'saab',
#   'wants',
#   'fdi',
#   'rules',
#   'tweaked',
#   '20',
#   'billion',
#   'fighter',
#   'jet',
#   'bid'],
#  ['snapshot', 'oscars', 'struggle', 'relevance'],
#  ['tech',
#   'bulls',
#   'samsung',
#   'puts',
#   'korea',
#   'back',
#   'map',
#   'taking',
#   'stock'],
#  ['walmart',
#   'slips',
#   'yet',
#   'another',
#   'overseas',
#   'obstacle',
#   'materializes'],
#  ['erdogan',
#   'makes',
#   'cheap',
#   'loans',
#   'central',
#   'plank',
#   'campaign',
#   'trail'],
#  ['bofa',
#   'seeks',
#   'rule',
#   'change',
#   'quicken',
#   'india',
#   's',
#   'bad',
#   'loan',
#   'clean',
#   'up'],
#  ['u',
#   'k',
#   's',
#   'flybe',
#   'attracts',
#   'counter',
#   'bid',
#   'american',
#   'air',
#   'backed',
#   'mesa'],
#  ['families', 'separated', 'search', 'fodder'],
#  ['london', 'judge', 'sets', 'five', 'possible', 'brexit', 'outcomes'],
#  ['stocks',
#   'may',
#   'volatile',
#   'fed',
#   'ditches',
#   'media',
#   'minutes',
#   'prep',
#   'period'],
#  ['fate', 'leveraged', 'loans', 'decided', 'cov', 'litealone'],
#  ['romanian', 'courts', 'prosecutors', 'get', 'new', 'blow', 'government'],
#  ['scary', 'subprime', 'auto', 'loans'],
#  ['finance',
#   'ministry',
#   'expects',
#   'rs',
#   '1',
#   '80',
#   'lakh',
#   'crore',
#   'bad',
#   'loan',
#   'recovery',
#   'march'],
#  ['jio', 'bsnl', 'added', 'mobile', 'users', 'december', 'trai', 'data'],
#  ['supreme', 'court', 'orders', 'eviction', '10', 'lakh', 'tribals'],
#  ['uday', 'kotak', 'wants', 'tech', 'giants', 'stay', 'away', 'banking'],
#  ['calf',
#   'brains',
#   'pig',
#   'snouts',
#   'u',
#   's',
#   'embraces',
#   'nose',
#   'to',
#   'tail',
#   'menus'],
#  ['la',
#   'z',
#   'boy',
#   'recliner',
#   'prices',
#   'rise',
#   'unless',
#   'trade',
#   'war',
#   'resolved'],
#  ['india',
#   'top',
#   'investment',
#   'destination',
#   'saudi',
#   'arabia',
#   'says',
#   'al',
#   'falih'],
#  ['pinera',
#   's',
#   'colombia',
#   'border',
#   'trip',
#   'carries',
#   'risks',
#   'chilean',
#   'leader'],
#  ['unilever', 'expects', 'hul', 'grow', 'much', 'faster'],
#  ['freezer', 'alarm', 'tolls'],
#  ['macron',
#   's',
#   'top',
#   'aides',
#   'face',
#   'possible',
#   'probe',
#   'bodyguard',
#   'scandal'],
#  ['takeover', 'frenzy', 'leads', 'frenzy', 'buyers', 'remorse'],
#  ['eu',
#   'wants',
#   'u',
#   'k',
#   'parliament',
#   'vote',
#   'brexit',
#   'deal',
#   'changes',
#   'final',
#   'summit'],
#  ['nonprofit', 'trying', 'upenddrug', 'costs', 'work', 'pharma'],
#  ['fed', 'minutes', 'shed', 'light', 'biggest', 'policy', 'reversal', 'years'],
#  ['deutsche',
#   'bank',
#   'weighed',
#   'extending',
#   'trump',
#   'loans',
#   'default',
#   'risk'],
#  ['getting', 'expensive', 'get', 'high'],
#  ['s',
#   'p',
#   '500s',
#   'dead',
#   'cat',
#   'bounce',
#   'finds',
#   'life',
#   'charts',
#   'heading',
#   'toward',
#   'record'],
#  ['fed',
#   'officials',
#   'saw',
#   'reasons',
#   'patience',
#   'amid',
#   'risks',
#   'minutes',
#   'show'],
#  ['tpg',
#   'sixth',
#   'street',
#   'seeks',
#   '2',
#   'billion',
#   'invest',
#   'growth',
#   'companies'],
#  ['analog',
#   'devices',
#   'leads',
#   'semiconductor',
#   'stocks',
#   'four',
#   'month',
#   'high'],
#  ['rift', 'u', 's', 'european', 'carriers', 'opens', 'huawei'],
#  ['egypt', 'basks', 'unprecedented', 'demand', '4', 'billion', 'bond', 'deal'],
#  ['five', 'things', 'need', 'know', 'start', 'day'],
#  ['iran', 'big', 'advantage', 'battle', 'middle', 'east'],
#  ['barclays',
#   'trader',
#   'goes',
#   'trial',
#   'criminal',
#   'front',
#   'running',
#   'claims'],
#  ['putin', 'isfinally', 'ready', 'look', 'homeward'],
#  ['may', 'could', 'forced', 'fire', 'ministers', 'brexit', 'rebellion'],
#  ['illinois',
#   'turns',
#   'warily',
#   'bonds',
#   'plug',
#   '134',
#   'billion',
#   'pension',
#   'hole'],
#  ['alibaba', 'show', 'hand', 'cicc', 'poker', 'game', 'tencent'],
#  ['five', 'takeaways', 'fed', 'minutes', 'january', 'meeting'],
#  ['venezuela', 'isnt', 'failed', 'state', 'afailure', 'left'],
#  ['jpmorgan', 'bofa', 'said', 'among', 'banks', 'market', 'ghana', 'eurobond'],
#  ['evil', 'good', 'latin', 'america'],
#  ['south',
#   'africa',
#   'forecasts',
#   '4',
#   '5',
#   'budget',
#   'gap',
#   'biggest',
#   'decade'],
#  ['apple',
#   'lawyer',
#   'charged',
#   'insider',
#   'case',
#   'released',
#   '500',
#   '000',
#   'bond'],
#  ['leveraged',
#   'loans',
#   'better',
#   'value',
#   'junk',
#   'bonds',
#   'investor',
#   'says'],
#  ['firebomb',
#   'exposes',
#   'east',
#   'europe',
#   's',
#   'struggle',
#   'media',
#   'freedom'],
#  ['glencore',
#   'plans',
#   'cap',
#   'coal',
#   'output',
#   'climate',
#   'shift',
#   'sources',
#   'say'],
#  ['ubs', 'men', 'meettax', 'justice'],
#  ['deja',
#   'vu',
#   'worst',
#   'emerging',
#   'market',
#   'currency',
#   'carry',
#   'trade',
#   'wavers'],
#  ['brexit',
#   'jobs',
#   'boom',
#   'flip',
#   'side',
#   'that',
#   's',
#   'holding',
#   'economy',
#   'back'],
#  ['shock',
#   'turns',
#   'hope',
#   'traders',
#   'bet',
#   's',
#   'africa',
#   'dodge',
#   'downgrade'],
#  ['fight',
#   'climate',
#   'change',
#   'use',
#   'recycled',
#   'toilet',
#   'paperand',
#   'less'],
#  ['cvs', 'feels', 'pain', 'potential', 'gain'],
#  ['goldman',
#   'sachs',
#   'plaintiffs',
#   'vie',
#   'lead',
#   'role',
#   '1mdb',
#   'group',
#   'suit'],
#  ['diagnosing',
#   'market',
#   'meltdown',
#   'fed',
#   'said',
#   'decembers',
#   'stock',
#   'plunge'],
#  ['illinois', 'governor', 'seeks', 'legalize', 'marijuana', 'sports', 'bets'],
#  ['cow',
#   'vigilantes',
#   'india',
#   'killed',
#   'least',
#   '44',
#   'people',
#   'report',
#   'finds'],
#  ['pboc',
#   'makes',
#   'first',
#   'use',
#   'new',
#   'tool',
#   'aimed',
#   'boosting',
#   'bank',
#   'capital'],
#  ['evening', 'briefing'],
#  ['u',
#   's',
#   'push',
#   'stable',
#   'yuan',
#   'may',
#   'unwind',
#   'china',
#   's',
#   'move',
#   'toward',
#   'markets'],
#  ['man',
#   'made',
#   'climate',
#   'change',
#   'causes',
#   'first',
#   'mammal',
#   'extinction'],
#  ['private', 'equity', 'may', 'coming', 'walmarts', 'asda'],
#  ['brexit', 'mean', 'eu', 'agency', 'break', 'canary', 'wharf', 'lease'],
#  ['may',
#   'suffers',
#   'first',
#   'brexit',
#   'defections',
#   'three',
#   'tories',
#   'quit'],
#  ['putin', 'says', 'russia', 'target', 'u', 's', 'missiles', 'put', 'europe'],
#  ['singapore', 'home', 'prices', 'set', 'big', 'bump', 'capitaland', 'says'],
#  ['sweet', 'tooth', 'grows', 'top', 'sugar', 'importer', 'buying', 'climb'],
#  ['hog', 'futures', 'crash', 'huge', 'supplies', 'cold', 'boosts', 'cattle'],
#  ['apple',
#   'amazon',
#   'lost',
#   'institutional',
#   'holders',
#   'late',
#   '2018',
#   'rout'],
#  ['new', 'york', 'city', 'already', 'lots', 'jobs', 'thank'],
#  ['shades',
#   '2007',
#   'volatility',
#   'markets',
#   'ignore',
#   'u',
#   's',
#   'recession',
#   'risk'],
#  ['sony', 'opens', 'internal', 'startup', 'program', 'anyone', 'idea'],
#  ['microsoft',
#   'says',
#   'russian',
#   'hackers',
#   'targeted',
#   'european',
#   'think',
#   'tanks'],
#  ['eu',
#   'says',
#   'romania',
#   'urgently',
#   'needs',
#   'put',
#   'reforms',
#   'back',
#   'track'],
#  ['climate',
#   'securitypanel',
#   'may',
#   'give',
#   'white',
#   'house',
#   'skeptics',
#   'new',
#   'voice'],
#  ['indonesia',
#   'decision',
#   'day',
#   'guide',
#   'rupiah',
#   'reprieve',
#   'offers',
#   'room',
#   'breathe'],
#  ['glencore', 'plans', 'new', 'buyback', 'trading', 'profit', 'disappoints'],
#  ['saudi', 'prince', 'pledges', 'help', 'india', 'fight', 'terror'],
#  ['palladium', 'stocks', 'remain', 'mystery', 'prices', 'surge', 'record'],
#  ['gipconsiders', 'selling', 'stake', 'terminal', 'investment', 'ltd'],
#  ['jay',
#   'newman',
#   'warns',
#   'investors',
#   'venezuelas',
#   'anti',
#   'creditor',
#   'army'],
#  ['storm', 'drop', 'snow', 'ice', 'rain', 'new', 'york'],
#  ['u', 's', 'china', 'real', 'currency', 'manipulator'],
#  ['trump', 'count', 'maduro', 'resistance', 'venezuela', 'spain', 'says'],
#  ['stocks',
#   'watch',
#   'coal',
#   'india',
#   'dr',
#   'reddys',
#   'jsw',
#   'steel',
#   'mahindra',
#   'cie',
#   'psu',
#   'banks'],
#  ['five', 'things', 'need', 'know', 'start', 'day'],
#  ['next',
#   'opec',
#   'headache',
#   'brazil',
#   's',
#   'burgeoning',
#   'crude',
#   'production'],
#  ['india', 'threatens', 'send', 'one', 'billionaires', 'jail'],
#  ['next', 'round', 'california', 'v', 'trump', 'trains'],
#  ['kalyani', 'group', 'eyes', 'new', 'opportunities', 'defence'],
#  ['glencore', 'brings', 'end', 'thermal', 'coal', 'step', 'closer'],
#  ['apple', 'plans', 'combining', 'iphone', 'ipad', 'mac', 'apps', '2021'],
#  ['u',
#   'k',
#   'cybersecurity',
#   'chief',
#   'says',
#   'decision',
#   'made',
#   'huawei',
#   'ban'],
#  ['garmin', 'surges', '11', 'year', 'high', 'smartwatches', 'fire'],
#  ['apple', 'skeptics', 'see', 'pain', 'ahead', 'weakness', 'china', 'em'],
#  ['cvs', 'predicts', 'ugly', '2019', 'closing', '68', 'billionaetna', 'deal'],
#  ['erdogan',
#   'says',
#   'turkey',
#   'can',
#   't',
#   'stand',
#   'alone',
#   'new',
#   'migration',
#   'wave'],
#  ['twitter', 'revises', 'data', 'russian', 'trolls', '2017', 'activity'],
#  ['zambian',
#   'central',
#   'bank',
#   'mulls',
#   'china',
#   'debt',
#   'swap',
#   'build',
#   'reserves'],
#  ['amazons',
#   'new',
#   'environmental',
#   'report',
#   'show',
#   'bad',
#   'two',
#   'day',
#   'shipping'],
#  ['careful', 'wish', 'for', 'strongmans', 'exit', 'leave', 'chaos'],
#  ['goldman',
#   's',
#   'oppenheimer',
#   'reckons',
#   'recession',
#   'fears',
#   'gone',
#   'far'],
#  ['laurene',
#   'powell',
#   'jobs',
#   'invests',
#   'reese',
#   'witherspoons',
#   'production',
#   'company'],
#  ['eoh',
#   'founders',
#   'quit',
#   'board',
#   'shake',
#   'up',
#   'scrutiny',
#   'intensifies'],
#  ['egypt',
#   'confronts',
#   'addiction',
#   'short',
#   'debt',
#   'rethinking',
#   'bond',
#   'plans'],
#  ['fed', 'confirms', 'dovish', 'market', 'thought'],
#  ['michael',
#   'cohen',
#   's',
#   'date',
#   'report',
#   'prison',
#   'delayed',
#   'two',
#   'months'],
#  ['qantas', 'recoup', 'surging', 'fuel', 'bill', 'strong', 'ticket', 'demand'],
#  ['praet',
#   'says',
#   'ecb',
#   'discuss',
#   'long',
#   'term',
#   'loans',
#   'soon',
#   'decision',
#   'unclear'],
#  ['americas',
#   'shale',
#   'boom',
#   'keeps',
#   'rolling',
#   'even',
#   'wildcatters',
#   'save',
#   'cash'],
#  ['trump', 'mccabe', 'justice', 'department', 'go', 'war'],
#  ['peru',
#   'raids',
#   'biggest',
#   'illegal',
#   'mines',
#   'stem',
#   'amazon',
#   'gold',
#   'rush'],
#  ['turkey',
#   'seeks',
#   'life',
#   'prison',
#   'businessman',
#   'kavala',
#   'gezi',
#   'case'],
#  ['sugar',
#   'millers',
#   'say',
#   'higher',
#   'msp',
#   'stabilise',
#   'margins',
#   'despite',
#   'glut'],
#  ['ghosn',
#   's',
#   'new',
#   'lawyer',
#   'says',
#   'prisoner',
#   'victim',
#   'nissan',
#   'conspiracy'],
#  ['barricks', 'cost', 'business', 'could', 'shoot', 'acacia', 'deal'],
#  ['whitney',
#   'baker',
#   'sees',
#   'economic',
#   'illiteracy',
#   'yuan',
#   'market',
#   'risk'],
#  ['clarida',
#   'says',
#   'fed',
#   'may',
#   'decide',
#   'soon',
#   'timing',
#   'asset',
#   'runoff',
#   'end'],
#  ['nestle',
#   'disney',
#   'pull',
#   'youtube',
#   'ads',
#   'joining',
#   'furor',
#   'child',
#   'videos'],
#  ['china',
#   's',
#   'li',
#   'asks',
#   'banks',
#   'supply',
#   'long',
#   'term',
#   'loans',
#   'economy'],
#  ['new', 'subprime', 'boom'],
#  ['supreme',
#   'court',
#   'finds',
#   'anil',
#   'ambani',
#   'guilty',
#   'contempt',
#   'ericsson',
#   'case'],
#  ['tria', 'cautions', 'stake', 'alitalia', 'league', 'backs', 'state', 'role'],
#  ['elon',
#   'musk',
#   'dials',
#   'back',
#   'tesla',
#   'production',
#   'forecast',
#   'hours',
#   'making'],
#  ['electric',
#   'cars',
#   'arechina',
#   'auto',
#   'industry',
#   's',
#   'lone',
#   'bright',
#   'spot'],
#  ['palladium',
#   'smashes',
#   '1',
#   '500',
#   'shortages',
#   'ignite',
#   'record',
#   'breaking',
#   'rally'],
#  ['dutch', 'consumer', 'sentiment', 'drops', 'lowest', 'four', 'years'],
#  ['former',
#   'fbi',
#   'chief',
#   'mccabe',
#   'urges',
#   'mueller',
#   'report',
#   'widely',
#   'released'],
#  ['china', 'delays', 'coal', 'imports', 'australia'],
#  ['government',
#   'infuse',
#   'rs',
#   '48',
#   '239',
#   'crore',
#   '12',
#   'state',
#   'run',
#   'banks'],
#  ['southwest', 'air', 'drops', '60', 'million', 'hit', 'u', 's', 'shutdown'],
#  ['u',
#   's',
#   'supreme',
#   'court',
#   'curbs',
#   'state',
#   'power',
#   'levy',
#   'fines',
#   'seize',
#   'property'],
#  ['brexit', 'accord', 'already', 'hammered', 'out', 'spain', 'says'],
#  ['rahul',
#   'gandhi',
#   's',
#   'congress',
#   'strikes',
#   'alliance',
#   'tamil',
#   'party',
#   'dmk'],
#  ['allianz',
#   'boosts',
#   'vc',
#   'fund',
#   '1',
#   '1',
#   'billion',
#   'tech',
#   'insurance',
#   'deals'],
#  ['eskom',
#   's',
#   '4',
#   '9',
#   'billion',
#   'bailout',
#   's',
#   'africa',
#   'budget',
#   'sees',
#   'debt',
#   'jump'],
#  ['sanctions', 'rock', 'concerts', 'still', 'maduro', 'may', 'go', 'soon'],
#  ['tilray',
#   'taps',
#   'u',
#   's',
#   'hemp',
#   'food',
#   'market',
#   'manitoba',
#   'harvest',
#   'deal'],
#  ['gtcr', 'led', 'groupnears', '5', '1', 'billion', 'deal', 'assuredpartners'],
#  ['global', 'recession', 'fear', 'suddenly', 'stalking', 'credit', 'market'],
#  ['oil',
#   'edges',
#   'report',
#   'shows',
#   'smaller',
#   'than',
#   'expected',
#   'crude',
#   'rise'],
#  ['debenhams', 'creditorsprepared', 'lend', 'ward', 'mike', 'ashley'],
#  ['brighter', 'days', 'could', 'ahead', 'chinas', 'gloomy', 'consumers'],
#  ['asia', 's', 'richest', 'delight', 'banks', 'abandoning', 'trading', 'egos'],
#  ['venezuela', 'tells', 'firms', 'open', 'accounts', 'inrussia', 'andturkey'],
#  ['big', 'sell', 'concho', 'bigger', 'hess', 'continental'],
#  ['eastern', 'europe', 'feeds', 'shrinking', 'ukraine'],
#  ['d', 'c', 'snowstorm', 'alters', 'fed', 'minutes', 'release'],
#  ['fed',
#   'minutes',
#   'show',
#   'officials',
#   'unsure',
#   'need',
#   'rate',
#   'hikes',
#   '2019'],
#  ['zimbabwe', 'devalues', 'quasi', 'currency', 'fx', 'regime', 'overhaul'],
#  ['swedish', 'debt', 'office', 'keeps', 'faith', 'krona', 'bet', 'paying'],
#  ['hedge',
#   'funds',
#   'coming',
#   'record',
#   'short',
#   'could',
#   'boost',
#   'gold',
#   'rally'],
#  ['bqdebates', 'covid', 'loan', 'book', 'healthcare', 'deployed'],
#  ['policies', 'decide', 'wins', 'indonesias', 'election'],
#  ['bad',
#   'bank',
#   'takes',
#   'shape',
#   'government',
#   'seen',
#   'playing',
#   'small',
#   'role'],
#  ['l',
#   't',
#   'infotech',
#   'expects',
#   'annual',
#   'wage',
#   'hikes',
#   'impact',
#   'q1',
#   'margin'],
#  ['need', 'know', 'going', 'trade', 'may', '6'],
#  ['rbi',
#   's',
#   'loan',
#   'recast',
#   'scheme',
#   'msmes',
#   'individuals',
#   'arrest',
#   'npa',
#   'formation',
#   'care',
#   'ratings'],
#  ['rupee', 'bond', 'update', 'may', '06', '2021', 'reliance', 'securities'],
#  ['l',
#   't',
#   'infotech',
#   'q4',
#   'review',
#   'confident',
#   'top',
#   'quartile',
#   'growth',
#   'dolat',
#   'capital'],
#  ['oracle',
#   'financial',
#   'q4',
#   'review',
#   'weak',
#   'deal',
#   'signings',
#   'leads',
#   'miss',
#   'dolat',
#   'capital'],
#  ['abb',
#   'power',
#   'q1',
#   'review',
#   'growth',
#   'momentum',
#   'continues',
#   'dolat',
#   'capital'],
#  ['coronavirus',
#   'india',
#   'updates',
#   '4',
#   'lakh',
#   'new',
#   'infections',
#   'nearly',
#   '4',
#   '000',
#   'deaths'],
#  ['agrochemicals',
#   'sector',
#   'update',
#   'diversification',
#   'insulate',
#   'companies',
#   'mancozeb',
#   'ban',
#   'eu',
#   'motilal',
#   'oswal'],
#  ['trump',
#   'says',
#   'kim',
#   'must',
#   'something',
#   'meaningful',
#   'end',
#   'sanctions'],
#  ['married',
#   'women',
#   'take',
#   'brunt',
#   'pandemic',
#   'hit',
#   'korean',
#   'employment'],
#  ['traders',
#   'push',
#   'inflation',
#   'gauge',
#   '13',
#   'year',
#   'high',
#   'debate',
#   'rages'],
#  ['musk', 'missteps', 'dredged', 'lawyer', 's', 'exit', 'misfired', 'tweet'],
#  ['giant',
#   'french',
#   'insect',
#   'farm',
#   'managed',
#   'robots',
#   'wins',
#   'new',
#   'investment'],
#  ['may', 'says', 'talks', 'solution', 'pick', 'pace', 'brexit', 'update'],
#  ['trump',
#   'warns',
#   'eu',
#   'car',
#   'tariffs',
#   'commerce',
#   'probe',
#   'offers',
#   'new',
#   'ammo'],
#  ['trump',
#   'says',
#   'u',
#   's',
#   'take',
#   'back',
#   'alabama',
#   'woman',
#   'joined',
#   'isis'],
#  ['starboard', 'nominates', 'five', 'directors', 'bristol', 'myers', 'board'],
#  ['hearing', 'without', 'listening', 'sound', 'tesla'],
#  ['abe',
#   'says',
#   'trump',
#   'pledges',
#   'support',
#   'missing',
#   'japanese',
#   'summit'],
#  ['u',
#   'k',
#   's',
#   'may',
#   'races',
#   'escape',
#   'brexit',
#   'impasse',
#   'tory',
#   'defections'],
#  ['blackrock', 'sees', 'pension', 'reform', 'cherry', 'top', 'brazil'],
#  ['gold', 'mining', 'etf', 'sees', 'turnover', 'u', 's', 'fund'],
#  ['apax',
#   's',
#   'one',
#   'call',
#   'said',
#   'reach',
#   'deal',
#   'holders',
#   'debt',
#   'swap'],
#  ['swiss',
#   'investment',
#   'firm',
#   'plans',
#   'dismissa',
#   'starbond',
#   'manager',
#   'misconduct'],
#  ['trudeau',
#   'unveil',
#   'new',
#   'budget',
#   'march',
#   '19',
#   'ahead',
#   'fall',
#   'election'],
#  ['tables', 'turning', 'emerging', 'markets'],
#  ['nyc', 'gateway', 'tunnel', 'gets', 'dose', 'cold', 'water', 'washington'],
#  ['u',
#   'k',
#   'rating',
#   'risk',
#   'downgrade',
#   'amid',
#   'no',
#   'deal',
#   'brexit',
#   'concern'],
#  ['steve',
#   'jobs',
#   'rival',
#   'hit',
#   'hard',
#   'times',
#   'makes',
#   'remarkable',
#   'comeback'],
#  ['goodwill', 'hunting', 'disaster', 'movie', 'china'],
#  ['rate', 'hike', 'start', 'firefighting', 'tunisia', 'central', 'bank'],
#  ['rates', 'traders', 'left', 'questions', 'fed', 'signals', 'end', 'runoff'],
#  ['housing', 'dream', 'turned', 'nightmare', 'spurs', 'backlash', 'australia'],
#  ['house',
#   'democrats',
#   'file',
#   'resolution',
#   'trump',
#   's',
#   'border',
#   'emergency'],
#  ['5', 'growth', '4', '9', 'billion', 'bailout', 'went', 'wrong'],
#  ['foreign', 'investors', 'favouring', 'bharti', 'infratel'],
#  ['ubs',
#   'faces',
#   'year',
#   'lost',
#   'earnings',
#   'shock',
#   'french',
#   'tax',
#   'verdict'],
#  ['worlds', 'apart', 'two', 'koreas', 'seven', 'decades', 'separation'],
#  ['trump',
#   'eu',
#   'far',
#   'apart',
#   'trade',
#   'kurz',
#   'says',
#   'meeting',
#   'president'],
#  ['china', 's', 'bonds', 'defaulting', 'record', 'pace'],
#  ['turks', 'dumping', 'liras', 'hoarding', 'dollars'],
#  ['push',
#   'toward',
#   'steady',
#   'chinese',
#   'yuan',
#   'expected',
#   'helpthe',
#   'euro'],
#  ['investors', 'cheer', 'brazil', 'pension', 'bill', 'brace', 'long', 'drama'],
#  ['zimbabwe', 's', 'inflation', 'rate', 'misread', 'ncube', 'says'],
#  ['americans', 'worry', 'retirement', 'much', 'europeans'],
#  ['fed', 'minutes', 'highlight', 'global', 'economic', 'challenges'],
#  ['u',
#   'k',
#   'nuclear',
#   'andmilitary',
#   'exporters',
#   'told',
#   'prepare',
#   'hard',
#   'brexit'],
#  ['samsungs', 'new', 'galaxy', 's10', 'compares', 'iphone', 'xs', 'max'],
#  ['swedbank', 'dirty', 'money', 'plot', 'thickens', 'ceo', 'analyst', 'call'],
#  ['coast',
#   'guard',
#   'officer',
#   'accused',
#   'plotting',
#   'kill',
#   'top',
#   'democrats'],
#  ['samsung', 'unveils', 'folding', 'phone', 'costs', '1', '980'],
#  ['samsung', 'revamps', 'flagship', 'range', '5g', 'low', 'cost', 'options'],
#  ['debt',
#   'pressures',
#   'nudge',
#   'rural',
#   'phone',
#   'companies',
#   'closer',
#   'edge'],
#  ['human', 'rights', 'key', 'north', 'korea', 'deal'],
#  ['tesla',
#   'would',
#   'be',
#   'customers',
#   'grouse',
#   'deposit',
#   'refunds',
#   'take',
#   'months'],
#  ['carving', 'pg', 'e', 'cities', 'others', 'offer', 'two', 'cents'],
#  ['get', 'ready', 'chinas', 'm', 'a', 'era'],
#  ['china', 's', 'rich', 'run', 'taxman', 'hiding', 'harder'],
#  ['u',
#   's',
#   'china',
#   'deal',
#   'enforcement',
#   'two',
#   'way',
#   'ex',
#   'officials',
#   'say'],
#  ['ex',
#   'goldman',
#   'banker',
#   's',
#   'quest',
#   'fresh',
#   'food',
#   'turns',
#   'hit',
#   'app'],
#  ['lyft', 'plans', 'file', 'ipo', 'soon', 'next', 'week'],
#  ['one', 'thing', 'could', 'derail', 'japans', 'sales', 'tax', 'hike'],
#  ['stanchart',
#   'take',
#   '900',
#   'million',
#   'charge',
#   'u',
#   's',
#   'u',
#   'k',
#   'probes'],
#  ['softbank',
#   's',
#   'fortress',
#   'invest',
#   '3',
#   '6',
#   'billion',
#   'japanese',
#   'property'],
#  ['tesla', 'cult', 'dealer', 'wonders', 'musk', 'takes', 'bite', 'bmw'],
#  ['u',
#   'a',
#   'e',
#   'says',
#   'qatar',
#   'embargo',
#   'stands',
#   'trade',
#   'ban',
#   'seemed',
#   'eased'],
#  ['fed',
#   'hints',
#   'bias',
#   'toward',
#   'hiking',
#   'endures',
#   'balance',
#   'sheet',
#   'rolloff',
#   'nears',
#   'end'],
#  ['saudi',
#   'prince',
#   'declares',
#   'release',
#   '850',
#   'indian',
#   'inmates',
#   'jails',
#   'mea'],
#  ['epa',
#   'said',
#   'weigh',
#   'ban',
#   'banks',
#   'role',
#   'biofuel',
#   'credit',
#   'review'],
#  ['turkish', 'food', 'inflationslows', 'cut', 'price', 'veggie', 'sales'],
#  ['le',
#   'maire',
#   'says',
#   'italian',
#   'recession',
#   'threatens',
#   'frances',
#   'economy'],
#  ['hna', 'talks', 'sell', 'london', 'building', '130', 'million', 'discount'],
#  ['u',
#   's',
#   'stocks',
#   'decline',
#   'bonds',
#   'fall',
#   'dollar',
#   'rises',
#   'markets',
#   'wrap'],
#  ['disruptive', 'ideas', 'happen', 'big', 'team'],
#  ['brazils',
#   'deadly',
#   'dam',
#   'collapse',
#   'could',
#   'force',
#   'mining',
#   'industry',
#   'change'],
#  ['group', 'requests', 'ethics', 'inquiry', 'interior', 'officials'],
#  ['l',
#   't',
#   'infotech',
#   'q4',
#   'review',
#   'robust',
#   'revenue',
#   'growth',
#   'continues',
#   'icici',
#   'direct'],
#  ['kids', 'tiktok', 'findthe', 'sunny', 'app', 'dark', 'side'],
#  ['97',
#   'year',
#   'old',
#   'tycoon',
#   'fourwives',
#   'push',
#   'revive',
#   'acasino',
#   'empire'],
#  ['howto', 'make', 'friends', 'road'],
#  ['philippines',
#   'sees',
#   'recent',
#   'lockdown',
#   'reversing',
#   'jobs',
#   'recovery'],
#  ['l',
#   't',
#   'infotech',
#   'q4',
#   'review',
#   'elevated',
#   'valuation',
#   'fairly',
#   'captures',
#   'future',
#   'growth',
#   'performance',
#   'motilal',
#   'oswal'],
#  ['u',
#   'k',
#   'rates',
#   'markets',
#   'start',
#   'mapping',
#   'path',
#   'higher',
#   'borrowing',
#   'costs'],
#  ['fonterra',
#   'may',
#   'buy',
#   'back',
#   'shareholders',
#   'fund',
#   'structural',
#   'overhaul'],
#  ['sony', 'sued', 'limiting', 'purchases', 'games', 'playstation', 'store'],
#  ['rbi',
#   'announces',
#   'measures',
#   'mitigate',
#   'impact',
#   'covid',
#   '2',
#   '0',
#   'motilal',
#   'oswal'],
#  ['greaves',
#   'cotton',
#   'q4',
#   'review',
#   'auto',
#   'lags',
#   'non',
#   'mobility',
#   'picks',
#   'up',
#   'icici',
#   'direct'],
#  ['top', 'idea', 'picks', 'may', 'krchoksey'],
#  ['ceat',
#   'q4',
#   'review',
#   'new',
#   'capex',
#   'likely',
#   'curtail',
#   'free',
#   'cash',
#   'flow',
#   'icici',
#   'securities'],
#  ['tata',
#   'steel',
#   'q4',
#   'review',
#   'deleveraging',
#   'key',
#   'highlight',
#   'quarter',
#   'icici',
#   'securities'],
#  ['idbi',
#   'bank',
#   'shares',
#   'jump',
#   'nearly',
#   'two',
#   'months',
#   'cabinets',
#   'privatisation',
#   'nod'],
#  ['european',
#   'loan',
#   'demand',
#   'plummets',
#   'record',
#   'breaking',
#   'rush',
#   'cash'],
#  ['blue', 'dart', 'q4', 'review', 'bulge', 'continues', 'icici', 'securities'],
#  ['sydney',
#   'imposes',
#   'masks',
#   'curbs',
#   'gatherings',
#   'due',
#   'virus',
#   'cases'],
#  ['hayden', 'adams', 'explains', 'uniswap', 'rise', 'defi'],
#  ['alphawave',
#   'holders',
#   'seek',
#   '1',
#   '1',
#   'billion',
#   'london',
#   'tech',
#   'listing'],
#  ['worlds',
#   'vaccine',
#   'trailblazer',
#   'shows',
#   'return',
#   'office',
#   'look',
#   'like'],
#  ['gunmen', 'release', '27', 'students', 'kidnapped', 'northern', 'nigeria'],
#  ['l',
#   't',
#   'infotech',
#   'q4',
#   'review',
#   'industry',
#   'leading',
#   'growth',
#   'prabhudas',
#   'lilladher'],
#  ['invest', '100', '000', 'asia', 'right'],
#  ['joshua',
#   'wongs',
#   'hong',
#   'kong',
#   'prison',
#   'sentence',
#   'keeps',
#   'getting',
#   'longer'],
#  ['unlikely',
#   'trade',
#   'japan',
#   'bonds',
#   'gets',
#   'revived',
#   'australian',
#   'funds'],
#  ['l',
#   't',
#   'tech',
#   'cyient',
#   'tata',
#   'elxsi',
#   'kpit',
#   'q4',
#   'review',
#   'demand',
#   'environment',
#   'seems',
#   'intact',
#   'prabhudas',
#   'lilladher'],
#  ['rbi',
#   's',
#   'covid',
#   'measures',
#   'liquidity',
#   'credit',
#   'support',
#   'restructuring',
#   '2',
#   '0',
#   'icici',
#   'securities'],
#  ['south',
#   'korea',
#   'sees',
#   'growing',
#   'economic',
#   'momentum',
#   'toward',
#   'full',
#   'recovery'],
#  ['automotive',
#   'axles',
#   'efficient',
#   'proxy',
#   'play',
#   'cyclical',
#   'recovery',
#   'commercial',
#   'vehicle',
#   'segment',
#   'icici',
#   'direct'],
#  ['climate', 'change', 'raising', 'sovereign', 'credit', 'risk', 'countries'],
#  ['l',
#   't',
#   'infotech',
#   'q4',
#   'review',
#   'set',
#   'much',
#   'stronger',
#   'growth',
#   'fy22',
#   'idbi',
#   'capital'],
#  ['new',
#   'yorks',
#   'luxury',
#   'rent',
#   'rebound',
#   'leaves',
#   'london',
#   'homes',
#   'doldrums'],
#  ['tesla', 'set', 'china', 'database', 'drivers', 'access', 'facts'],
#  ['san',
#   'miguels',
#   'profit',
#   'surges',
#   '15x',
#   'oil',
#   'food',
#   'power',
#   'units',
#   'recover'],
#  ['construction', 'infra', 'sector', 'monthly', 'update', 'dolat', 'capital'],
#  ['infrastructure', 'projects', 'get', 'tax', 'relief', 'supreme', 'court'],
#  ['chinese',
#   'vendors',
#   'give',
#   'indian',
#   'solar',
#   'farms',
#   'new',
#   'headache',
#   'pandemic'],
#  ['bidens', 'cop', 'out', 'morocco', 'serves', 'purpose'],
#  ['kkr',
#   'backed',
#   'pepper',
#   'money',
#   'expands',
#   'australias',
#   'biggest',
#   'ipo',
#   '2021'],
#  ['nigeria',
#   'extends',
#   'incentive',
#   'period',
#   'boost',
#   'dollar',
#   'remittances'],
#  ['malaysia',
#   'holds',
#   'key',
#   'rate',
#   'all',
#   'time',
#   'low',
#   'sees',
#   'downside',
#   'risks'],
#  ['analysts',
#   'remain',
#   'bullish',
#   'tata',
#   'steel',
#   'citing',
#   'deleveraging',
#   'expansion',
#   'plan'],
#  ['top',
#   'global',
#   'medical',
#   'companies',
#   'seek',
#   'g',
#   '20',
#   'protection',
#   'patents'],
#  ['graft',
#   'crackdown',
#   'south',
#   'africas',
#   'anc',
#   'boosts',
#   'election',
#   'prospects'],
#  ['oil', 'company', 'becomes', 'renewables', 'company'],
#  ['sensex',
#   'nifty',
#   'gain',
#   'second',
#   'day',
#   'rally',
#   'metal',
#   'stocks',
#   'continues'],
#  ['alcohol', 'deaths', 'jump', '20', 'record', 'england', 'wales'],
#  ['economy',
#   'roundup',
#   'financial',
#   'conditions',
#   'improved',
#   'moderately',
#   'april',
#   'icici',
#   'securities'],
#  ['singapore', 'press', 'spin', 'media', 'non', 'profit', 'entity'],
#  ['von',
#   'der',
#   'leyen',
#   'defends',
#   'eu',
#   'vaccination',
#   'drive',
#   'exports',
#   'rise'],
#  ['adidas',
#   'nike',
#   'web',
#   'sales',
#   'plunge',
#   'china',
#   'amid',
#   'xinjiang',
#   'boycott'],
#  ['japans',
#   'suga',
#   'decide',
#   'friday',
#   'tokyo',
#   'virus',
#   'emergency',
#   'extension'],
#  ['u', 's', 'russia', 'collision', 'course', 'black', 'sea'],
#  ['unicredits', 'orcel', 'says', 'hes', 'open', 'deals', 'restore', 'growth'],
#  ['adani',
#   'ports',
#   'q4',
#   'review',
#   'in',
#   'line',
#   'performance',
#   'continued',
#   'focus',
#   'cash',
#   'flows',
#   'centrum',
#   'broking'],
#  ['yellens',
#   'challenge',
#   'hiring',
#   'problems',
#   'inflation',
#   'debate',
#   'eco',
#   'day'],
#  ['nintendo', 'shows', 'play', 'pandemic'],
#  ['make', 'billions', 'supply', 'chain', 'bottlenecks'],
#  ['boe',
#   'rate',
#   'call',
#   'ecb',
#   'downplays',
#   'inflation',
#   'fed',
#   'hawks',
#   'agree',
#   'eco',
#   'day'],
#  ['turkey',
#   'governor',
#   'bet',
#   'inflation',
#   'peaked',
#   'decision',
#   'day',
#   'guide'],
#  ['vw',
#   'gets',
#   'emissions',
#   'help',
#   'due',
#   'slower',
#   'ev',
#   'uptake',
#   'outside',
#   'europe'],
#  ['socgen',
#   'sees',
#   'three',
#   'day',
#   'homeworking',
#   'ing',
#   'plans',
#   '50',
#   'office',
#   'week'],
#  ['charts',
#   'mamata',
#   'banerjee',
#   'scripted',
#   'record',
#   'win',
#   'west',
#   'bengal'],
#  ['africa',
#   'cdc',
#   'welcome',
#   'u',
#   's',
#   'support',
#   'vaccine',
#   'patent',
#   'waiver'],
#  ['turkey',
#   'holds',
#   'rates',
#   'central',
#   'banker',
#   'bets',
#   'inflation',
#   'peaked'],
#  ['melinda', 'french', 'gates', 'gets', 'billions', 'shares', 'cascade'],
#  ['moderna',
#   'falls',
#   'u',
#   's',
#   'patent',
#   'proposal',
#   'covid',
#   'vaccine',
#   'sales',
#   'miss'],
#  ['startup', 'gong', 'seeks', 'new', 'funds', '7', 'billion', 'value'],
#  ['europe', 'coldest', 'april', 'almost', 'two', 'decades'],
#  ['fly', 'right', 'now', 'americans', 'jet', 'south', 'caribbean', 'beaches'],
#  ['olympic',
#   'athletes',
#   'receive',
#   'vaccines',
#   'donated',
#   'pfizer',
#   'biontech'],
#  ['biden', 'tuition', 'plan', 'boosts', 'colleges', 'students'],
#  ['zimbabwe',
#   'list',
#   'bond',
#   'local',
#   'bourse',
#   'first',
#   'time',
#   '20',
#   'years'],
#  ['unrest',
#   'roiling',
#   'colombia',
#   'may',
#   'hit',
#   'economy',
#   'central',
#   'banker',
#   'says'],
#  ['russia',
#   'says',
#   'one',
#   'shot',
#   'sputnik',
#   'light',
#   'vaccine',
#   '79',
#   'efficacy'],
#  ['boe', 'watchers', 'look', 'signs', 'tightening', 'ahead', 'decisionguide'],
#  ['fresh',
#   'lockdowns',
#   'create',
#   'pothole',
#   'canadas',
#   'road',
#   'jobs',
#   'recovery'],
#  ['weber', 'says', 'ubs', 'consider', 'chairwoman', 'leaves'],
#  ['u',
#   's',
#   'lng',
#   'players',
#   'tout',
#   'carbon',
#   'capture',
#   'bid',
#   'boost',
#   'green',
#   'image'],
#  ['ireland',
#   'assails',
#   'possible',
#   'u',
#   'k',
#   'northern',
#   'ireland',
#   'amnesty',
#   'plan'],
#  ['payday', 'lenders', 'didnt', 'get', 'boost', 'pandemics', 'hard', 'times'],
#  ['u',
#   's',
#   'mortgage',
#   'rates',
#   'slip',
#   'lowest',
#   'level',
#   'almost',
#   'three',
#   'months'],
#  ['ethiopia',
#   'declares',
#   'tigray',
#   'oromia',
#   'groups',
#   'terrorist',
#   'organizations'],
#  ['broken', 'ventilators', 'add', 'momentum', 'right', 'repairmovement'],
#  ['hero',
#   'motocorp',
#   'q4',
#   'results',
#   'profit',
#   'beats',
#   'estimates',
#   'despite',
#   'decline'],
#  ['bayer', 'loses', 'fight', 'chemicals', 'eu', 'blamed', 'killing', 'bees'],
#  ['regeneron', 'sees', 'demand', 'covid', 'therapy', 'vaccinations', 'drop'],
#  ['british', 'workers', 'spend', 'time', 'office', 'lockdown', 'eases'],
#  ['zimbabwe', 'home', 'elephants', 'lions', 'taxes', 'wildlife', 'trade'],
#  ['trump',
#   'lost',
#   'key',
#   'defense',
#   'tax',
#   'return',
#   'fight',
#   'democrats',
#   'say'],
#  ['nycs',
#   'financial',
#   'district',
#   'condos',
#   'pile',
#   'office',
#   'life',
#   'retreats'],
#  ['socgen',
#   'posts',
#   'rebound',
#   'best',
#   'equities',
#   'revenue',
#   'since',
#   '2015'],
#  ['paschi',
#   'posts',
#   'surprise',
#   'profit',
#   'sees',
#   'lower',
#   'capital',
#   'shortfall'],
#  ['air', 'france', 'klm', 'weighs', 'fresh', 'fundraising', 'losses', 'mount'],
#  ['pfizer', 'biontech', 'supply', '3', 'billion', 'vaccine', 'doses', 'year'],
#  ['arcelormittal', 'expects', '2021', 'steel', 'consumption', 'rise', 'india'],
#  ['eu',
#   'ready',
#   'discuss',
#   'u',
#   's',
#   'plan',
#   'waive',
#   'vaccine',
#   'patent',
#   'protection'],
#  ['french',
#   'fishing',
#   'boats',
#   'begin',
#   'leaving',
#   'jersey',
#   'waters',
#   'brexit',
#   'update'],
#  ['boe',
#   'slows',
#   'bond',
#   'buying',
#   'u',
#   'k',
#   'economic',
#   'recovery',
#   'gathers',
#   'pace'],
#  ['could', 'next', 'space', 'station', 'hotel'],
#  ['german',
#   'factory',
#   'orders',
#   'rise',
#   'european',
#   'economy',
#   'turns',
#   'corner'],
#  ['biden',
#   'tax',
#   'hike',
#   'exemption',
#   'farms',
#   'pushed',
#   'rural',
#   'democrats'],
#  ['south',
#   'african',
#   'investors',
#   'see',
#   'long',
#   'road',
#   'ahead',
#   'graft',
#   'crackdown'],
#  ['crypto',
#   'exchange',
#   'ftx',
#   'launcheslumber',
#   'futuresafter',
#   'two',
#   'hours',
#   'work'],
#  ['uber', 'lyft', 's', 'drivers', 'call', 'shots'],
#  ['zambian', 'government', 'denies', 'kcm', 'shut'],
#  ['italy', 'drop', 'backing', 'telecom', 'italia', 'single', 'network'],
#  ['gamestop', 'fallout', 'sparks', 'washington', 'fight', 'market', 'rules'],
#  ['jpmorgan', 'move', 'another', '200', 'billion', 'assets', 'brexit'],
#  ['mcconnell',
#   'says',
#   'u',
#   's',
#   'afghan',
#   'withdrawal',
#   'means',
#   'return',
#   'taliban'],
#  ['rise', 'mega', 'companies', 'may', 'damage', 'global', 'economy'],
#  ['clean',
#   'energys',
#   '18',
#   'billion',
#   'boom',
#   'spawns',
#   'double',
#   'leveraged',
#   'etfs'],
#  ['ibm',
#   'downgraded',
#   's',
#   'p',
#   'deal',
#   'spree',
#   'clouds',
#   'ability',
#   'cut',
#   'debt'],
#  ['pretty',
#   'damn',
#   'awful',
#   'covid',
#   'long',
#   'haulers',
#   'find',
#   'mental',
#   'care',
#   'elusive'],
#  ['biden', 'enlists', 'ranchers', 'tribes', 'conserve', '30', 'land', 'water'],
#  ['tax', 'rich', 'heres', 'biden', 'forgot'],
#  ['trump',
#   'set',
#   'lower',
#   'tax',
#   'bill',
#   'wall',
#   'street',
#   'tower',
#   'value',
#   'slips'],
#  ['trading',
#   'card',
#   'mania',
#   'inspires',
#   'new',
#   'reality',
#   'tv',
#   'show',
#   'makerofpawn',
#   'stars'],
#  ['david',
#   'swensen',
#   'yale',
#   'endowments',
#   'pioneer',
#   'manager',
#   'dies',
#   '67'],
#  ['n',
#   'y',
#   'blasts',
#   'broadband',
#   'firms',
#   'fake',
#   'net',
#   'neutrality',
#   'comments'],
#  ['iron',
#   'ore',
#   'joins',
#   'steel',
#   'hitting',
#   'record',
#   'china',
#   'demand',
#   'unleashed'],
#  ['elizabeth', 'holmes', 'use', 'puffery', 'defense', 'could', 'itwork'],
#  ['qatar', 'orders', 'arrest', 'finance', 'minister', 'misuse', 'funds'],
#  ['electric',
#   'truck',
#   'startup',
#   'raises',
#   '110',
#   'million',
#   'fuel',
#   'expansion'],
#  ['yang',
#   'makes',
#   'first',
#   'tv',
#   'ad',
#   'purchase',
#   'nyc',
#   'mayors',
#   'race',
#   'tightens'],
#  ['big',
#   'bankruptcies',
#   'vanish',
#   'longest',
#   'period',
#   'since',
#   'pandemic',
#   'hit'],
#  ['real',
#   'estate',
#   'frenzy',
#   'crest',
#   '2021',
#   'canadas',
#   'housing',
#   'agency',
#   'says'],
#  ['quiet', 'placestars', 'think', 'paramount', 'owes', 'money'],
#  ['n',
#   'y',
#   'accuses',
#   'activists',
#   'using',
#   'robocall',
#   'limit',
#   'black',
#   'vote'],
#  ['china',
#   'must',
#   'responsible',
#   'falling',
#   'rocket',
#   'u',
#   's',
#   'lawmaker',
#   'says'],
#  ['banks',
#   'seek',
#   'bidens',
#   'aid',
#   'trumps',
#   '1',
#   '000',
#   'sanctions',
#   'a',
#   'year',
#   'pace'],
#  ['eqt', 'buy', 'appalachia', 'shale', 'gas', 'assets', '2', '9', 'billion'],
#  ['norwegian',
#   'cruise',
#   'ceo',
#   'rules',
#   'july',
#   'u',
#   's',
#   'start',
#   'shares',
#   'drop'],
#  ['australias',
#   'budget',
#   'position',
#   'be25',
#   'better',
#   'december',
#   'estimate',
#   'economists'],
#  ['u',
#   's',
#   'housing',
#   'regulator',
#   'eyes',
#   'rules',
#   'curb',
#   'short',
#   'term',
#   'rental',
#   'risk'],
#  ['tesla', 'gains', 'report', 'already', 'sold', 'quarter'],
#  ['stifel',
#   'pressured',
#   'drop',
#   'controversial',
#   'alabama',
#   'prison',
#   'bond',
#   'deal'],
#  ['hilltop',
#   'securities',
#   'sues',
#   'ex',
#   'employee',
#   'stealing',
#   'client',
#   'data'],
#  ['britons', 'vote', 'key', 'elections', 'future', 'scotland', 'stake'],
#  ['imf',
#   'sees',
#   'strong',
#   'economic',
#   'arguments',
#   'removing',
#   'vaccine',
#   'barriers'],
#  ['bitcoin',
#   'traders',
#   'u',
#   's',
#   'lack',
#   'investor',
#   'protections',
#   'gensler',
#   'says'],
#  ['sun',
#   'life',
#   'eyes',
#   'efficiency',
#   'bump',
#   'taking',
#   'covid',
#   'habits',
#   'back',
#   'office'],
#  ['aston',
#   'martin',
#   'revenue',
#   'tops',
#   'estimates',
#   'suv',
#   'drives',
#   'volumes'],
#  ['shooting',
#   'popularity',
#   'means',
#   'vista',
#   'outdoor',
#   'pass',
#   'higher',
#   'costs'],
#  ['covid', 'made', 'orlando', 'less', 'affordable', 'san', 'francisco'],
#  ['european',
#   'banks',
#   'present',
#   'clean',
#   'sweep',
#   'consensus',
#   'beating',
#   'results'],
#  ['roku',
#   'rallies',
#   'strong',
#   'sales',
#   'forecast',
#   'amid',
#   'streaming',
#   'growth'],
#  ['ge',
#   'buys',
#   'french',
#   'startup',
#   'bolster',
#   'breast',
#   'cancer',
#   'diagnostics'],
#  ['airbus', 'sees', 'china', 'muscling', 'rivalry', 'boeing', '2030'],
#  ['astra',
#   'confident',
#   'shareholders',
#   'back',
#   '39',
#   'billion',
#   'alexion',
#   'deal'],
#  ['aussie',
#   'dollar',
#   'falls',
#   'prey',
#   'china',
#   'rift',
#   'even',
#   'commodities',
#   'soar'],
#  ['chinese',
#   'travel',
#   'booms',
#   'spending',
#   'still',
#   'lags',
#   'pre',
#   'covid',
#   'levels'],
#  ['bidens',
#   'vaccine',
#   'path',
#   'gets',
#   'tougher',
#   'pace',
#   'shots',
#   'slows',
#   '37'],
#  ['fraud', 'prevention', 'startup', 'riskified', 'explores', '2021', 'ipo'],
#  ['japan',
#   'andsouth',
#   'korea',
#   'air',
#   'differences',
#   'u',
#   's',
#   'seeks',
#   'unity'],
#  ['shake',
#   'shack',
#   'plunges',
#   'first',
#   'quarter',
#   'sales',
#   'miss',
#   'expectations'],
#  ['china',
#   'faces',
#   'growth',
#   'headwinds',
#   'manufacturing',
#   'citigroup',
#   'says'],
#  ['u',
#   's',
#   'eviction',
#   'moratorium',
#   'reinstated',
#   'judge',
#   'considers',
#   'case'],
#  ['19th', 'century', 'theory', 'explains', 'consumers', 'may', 'splurge'],
#  ['treasury', 'might', 'hold', 'debt', 'cap', 'reckoning', 'least', 'october'],
#  ['beyond',
#   'meat',
#   'shares',
#   'tumble',
#   'restaurant',
#   'closures',
#   'weigh',
#   'sales'],
#  ['monde', 'nissin', 'raise', '1', 'billion', 'philippines', 'biggest', 'ipo'],
#  ['commodities',
#   'boom',
#   'grips',
#   'steel',
#   'arcelormittal',
#   'profit',
#   'surges'],
#  ['build', 'wall', 'co', 'founder', 'kolfage', 'indicted', 'tax', 'case'],
#  ['coinbase', 'plunges', 'all', 'time', 'low', 'ipo', 'etf', 'freefall'],
#  ['mckinsey', 'targeted', 'school', 'districts', 'opioid', 'related', 'costs'],
#  ['get', 'thailand', 'campaign', 'gains', 'momentum', 'covid', 'grows'],
#  ['biden', 'coming', 'tax', 'loopholes', 'rich', 'cherish'],
#  ['amc',
#   'posts',
#   '567',
#   'million',
#   'loss',
#   'reveling',
#   'meme',
#   'stock',
#   'boom'],
#  ['mitsui', 'weighs', 'buyout', '11', 'billion', 'ihh', 'healthcare'],
#  ['facebook', 'removes', 'inauthentic', 'networks', 'palestine', 'ukraine'],
#  ['google', 'make', 'android', 'apps', 'tell', 'users', 'data', 'collection'],
#  ['job',
#   'openings',
#   'u',
#   's',
#   'small',
#   'businesses',
#   'increase',
#   'fresh',
#   'record'],
#  ['cable', 'firms', 'fear', 'left', 'dust', 'biden', 'broadband', 'quest'],
#  ['rbi',
#   'cash',
#   'yields',
#   'draw',
#   'investors',
#   'dollar',
#   'bonds',
#   'india',
#   'credit'],
#  ['heres', 'else', 'therbi', 'pandemic', 'rages'],
#  ['risk',
#   'binge',
#   'u',
#   's',
#   'pressures',
#   'china',
#   'bankers',
#   'blame',
#   'eco',
#   'day'],
#  ['china',
#   'fires',
#   'back',
#   'g',
#   '7',
#   'shows',
#   'united',
#   'front',
#   'toward',
#   'beijing'],
#  ['copper',
#   'iron',
#   'ore',
#   'surge',
#   'chinese',
#   'investors',
#   'unleash',
#   'demand'],
#  ['indian',
#   'virus',
#   'variant',
#   'found',
#   'three',
# ...
#  ['woke', 'cia', 'makeamerica', 'safer'],
#  ['rbi',
#   'asks',
#   'banks',
#   'create',
#   'covid',
#   'loan',
#   'book',
#   'support',
#   'health',
#   'sector'],
#  ['fauci',
#   'cdc',
#   'summer',
#   'camp',
#   'guidance',
#   'stringent',
#   'may',
#   'adjusted'],
#  ['indian',
#   'delegation',
#   'self',
#   'isolates',
#   'g',
#   '7',
#   'meeting',
#   'top',
#   'diplomats'],
#  ['u', 's', 'births', 'drop', 'lowest', 'level', 'since', '1970s'],
#  ['canada', 'approves', 'pfizer', 'covid', 'shot', 'adolescents'],
#  ['trump', 'remains', 'banned', 'facebook', 'oversight', 'board', 'rules'],
#  ['new',
#   'petrobras',
#   'ceo',
#   'hot',
#   'seat',
#   'fuel',
#   'prices',
#   'oil',
#   'climbing'],
#  ['u',
#   'k',
#   'eu',
#   'reach',
#   'deal',
#   'give',
#   'blocs',
#   'envoy',
#   'full',
#   'diplomatic',
#   'status'],
#  ['white', 'house', 'says', 'businesses', 'hike', 'wages', 'good', 'thing'],
#  ['actress',
#   'turned',
#   'mogul',
#   'alba',
#   'makes',
#   '122',
#   'million',
#   'honest',
#   'ipo'],
#  ['india',
#   'plans',
#   'privatize',
#   'idbi',
#   'bank',
#   'seek',
#   'strategic',
#   'investor'],
#  ['dogecoin', 'joke', 'turning', 'serious', 'latest', 'crypto', 'binge'],
#  ['sec',
#   'chief',
#   'signals',
#   'new',
#   'rules',
#   'could',
#   'threaten',
#   'robinhood',
#   'citadel'],
#  ['fauci', 'sees', 'pfizer', 'shot', 'clearance', 'teens', 'within', 'days'],
#  ['can', 't', 'hold', 'bankruptcy', 'wave', 'forever'],
#  ['foil',
#   'maker',
#   'reynolds',
#   'sees',
#   'three',
#   'rounds',
#   'price',
#   'hikes',
#   '2021'],
#  ['merkel', 'braces', 'possible', 'court', 'setback', 'lockdown', 'law'],
#  ['services', 'u', 's', 'expand', 'second', 'strongest', 'pace', 'record'],
#  ['eu', 'investment', 'deal', 'china', 'held', 'beijings', 'sanctions'],
#  ['colombia', 'fight', 'keep', 'bond', 'rating', 'finance', 'chief', 'says'],
#  ['u',
#   's',
#   'covid',
#   'cases',
#   'could',
#   'see',
#   'sharp',
#   'decline',
#   'july',
#   'cdc',
#   'says'],
#  ['u',
#   's',
#   'refinery',
#   'insights',
#   'west',
#   'coast',
#   'fuel',
#   'plant',
#   'finds',
#   'buyer'],
#  ['ecbs', 'lane', 'rebuffs', 'prospect', 'lasting', 'surge', 'inflation'],
#  ['norways',
#   'first',
#   'interest',
#   'rate',
#   'hike',
#   'isnt',
#   'far',
#   'off',
#   'decision',
#   'guide'],
#  ['wazirx',
#   'became',
#   'indias',
#   'largest',
#   'cryptocurrency',
#   'exchange',
#   'kickstarted',
#   'crypto',
#   'revolution',
#   'india'],
#  ['thailand',
#   'holds',
#   'rates',
#   'warns',
#   'growth',
#   'amid',
#   'worst',
#   'covid',
#   'wave'],
#  ['eqt', 'stonepeak', 'prepare', 'long', 'haul', 'kpn', 'rebuffs', 'approach'],
#  ['tsmc', 's', 'global', 'not', 'global', 'strategy', 'mustend'],
#  ['record',
#   'zambian',
#   'corn',
#   'crop',
#   'may',
#   'prove',
#   'bad',
#   'news',
#   'bondholders'],
#  ['coinbase', 'plans', 'close', 'san', 'francisco', 'headquarters', '2022'],
#  ['diamonds', 'atlas', 'marareceivesapproaches', 'africa', 'assets'],
#  ['corns', 'hot', 'summers', 'tend', 'last'],
#  ['boris',
#   'johnson',
#   'makes',
#   'last',
#   'pitch',
#   'voters',
#   'u',
#   'k',
#   'super',
#   'thursday',
#   'polls'],
#  ['oil',
#   'rally',
#   'pauses',
#   'investors',
#   'weigh',
#   'rising',
#   'gasoline',
#   'supplies'],
#  ['macrons',
#   'halfhearted',
#   'criticismof',
#   'napoleon',
#   'rooted',
#   'election',
#   'math'],
#  ['treasury',
#   'warns',
#   'u',
#   's',
#   'debt',
#   'limit',
#   'tools',
#   'may',
#   'run',
#   'faster'],
#  ['me', 'jack', 'united', 'kingdom', 'fraying'],
#  ['top', 'wind', 'turbine', 'maker', 'plans', 'raise', 'prices'],
#  ['lumber',
#   'futures',
#   'extend',
#   'record',
#   'rally',
#   'top',
#   '1',
#   '500',
#   'first',
#   'time'],
#  ['saudi',
#   'arabia',
#   'cuts',
#   'oil',
#   'prices',
#   'asia',
#   'india',
#   'battles',
#   'virus'],
#  ['emirates',
#   'fits',
#   'upscale',
#   'coach',
#   'class',
#   'a380s',
#   'market',
#   'mutates'],
#  ['altrad',
#   'talks',
#   '1',
#   '8',
#   'billion',
#   'bilfinger',
#   'deal',
#   'fall',
#   'apart'],
#  ['global',
#   'minimum',
#   'tax',
#   'near',
#   '21',
#   'feasible',
#   'oecd',
#   'official',
#   'says'],
#  ['merkel', 'keeps', 'curfew', 'powers', 'emergency', 'court', 'review'],
#  ['worlds', 'largest', 'pension', 'fund', 'cooled', 'esg', 'you'],
#  ['cheneys', 'grip', 'gop', 'job', 'weakens', 'trump', 'backs', 'replacement'],
#  ['hawks',
#   'new',
#   'doves',
#   'global',
#   'vaccine',
#   'race',
#   'u',
#   's',
#   'waiver',
#   'eco',
#   'day'],
#  ['malaysia',
#   'hold',
#   'rate',
#   'virus',
#   'uncertainty',
#   'looms',
#   'decision',
#   'guide'],
#  ['eus',
#   'breton',
#   'says',
#   'time',
#   'fix',
#   'naive',
#   'approach',
#   'chip',
#   'supply'],
#  ['wazirx',
#   'doge',
#   'frenzy',
#   'sends',
#   'indias',
#   'largest',
#   'crypto',
#   'exchange',
#   'dogehouse'],
#  ['tata',
#   'steel',
#   'reaps',
#   'bumper',
#   'profit',
#   'price',
#   'rally',
#   'demand',
#   'upturn'],
#  ['peloton',
#   'recall',
#   'tests',
#   'analyst',
#   'devotion',
#   'stock',
#   'slump',
#   'deepens'],
#  ['rbi', 'steps', 'loan', 'relief', 'liquidity', 'indias', 'virus', 'fight'],
#  ['climate', 'laggard', 'nation', 'still', 'attracts', 'investments'],
#  ['bidens',
#   'fed',
#   'choices',
#   'add',
#   'uncertainty',
#   'inflation',
#   'wary',
#   'investors'],
#  ['comes', 'covid', '19', 'community', 'corps', 'want'],
#  ['credit',
#   'suisse',
#   'boosts',
#   'asia',
#   'hiring',
#   'tap',
#   'fast',
#   'growing',
#   'markets'],
#  ['warburg', 'pincusweighs', 'sale', 'explorer', 'hawkwood', 'energy'],
#  ['rapidly',
#   'spreading',
#   'variants',
#   'compound',
#   'africas',
#   'coronavirus',
#   'woes'],
#  ['stefaniks', 'rise', 'house', 'gop', 'power', 'fueled', 'loyalty', 'trump'],
#  ['mcconnell', 'relies', 'silent', 'treatment', 'deflect', 'trump', 'attacks'],
#  ['el',
#   'salvador',
#   'defends',
#   'firing',
#   'attorney',
#   'general',
#   'top',
#   'judges'],
#  ['carval', 'investors', 'lines', '490', 'million', 'clean', 'energy', 'fund'],
#  ['kolanovic', 'warns', 'money', 'managers', 'risk', 'inflation', 'shock'],
#  ['covid',
#   'pushed',
#   'nearly',
#   '23',
#   'crore',
#   'indians',
#   'poverty',
#   'estimates',
#   'study'],
#  ['tesla', 'losing', 'source', 'credit', 'revenue', 'thats', 'key', 'profits'],
#  ['fed', 'hawks', 'join', 'chorus', 'playing', 'worries', 'inflation'],
#  ['amazon',
#   'work',
#   'rules',
#   'govern',
#   'tweets',
#   'body',
#   'odor',
#   'contract',
#   'drivers'],
#  ['honest',
#   'co',
#   'jumps',
#   'debut',
#   'alba',
#   'keep',
#   'raising',
#   'fourth',
#   'kid'],
#  ['new',
#   'sunpower',
#   'ceo',
#   'wants',
#   'buying',
#   'solar',
#   'easy',
#   'amazon',
#   'purchases'],
#  ['gold',
#   'ceo',
#   'blasts',
#   'hysterical',
#   'investors',
#   'chasing',
#   'quick',
#   'cash'],
#  ['citadel',
#   'taps',
#   'phillip',
#   'lee',
#   'run',
#   'surveyor',
#   'todd',
#   'barker',
#   'retires'],
#  ['deutsche', 'bank', 'gets', 'coco', 'bond', 'party', 'going'],
#  ['spacex', 'nails', 'landing', 'fifth', 'test', 'starship', 'rocket'],
#  ['pent',
#   'up',
#   'u',
#   's',
#   'travel',
#   'demand',
#   'poised',
#   'trigger',
#   '30',
#   'surge',
#   'jet',
#   'fuel',
#   'use'],
#  ['national', 'australia', 'bank', 'profit', 'surges', 'economic', 'recovery'],
#  ['indias',
#   'struggle',
#   'track',
#   'new',
#   'covid',
#   'variants',
#   'could',
#   'worsen',
#   'crisis'],
#  ['novogratzs',
#   'galaxy',
#   'buys',
#   'bitgo',
#   '1',
#   '2',
#   'billion',
#   'crypto',
#   'deal'],
#  ['facebook', 'chided', 'review', 'board', 'vague', 'rules', 'trump', 'case'],
#  ['tata',
#   'steel',
#   'q4',
#   'results',
#   'profit',
#   'surges',
#   '80',
#   'higher',
#   'sales',
#   'prices'],
#  ['hungary', 'population', 'drop', 'biggest', '102', 'years', 'virus'],
#  ['sculptor',
#   'hedge',
#   'fund',
#   'rebounds',
#   'first',
#   'inflows',
#   'since',
#   '2014'],
#  ['onex', 'makes', 'fresh', 'attempt', 'sell', '1', 'billion', 'carestream'],
#  ['zimbabwe',
#   'considers',
#   'mass',
#   'elephant',
#   'killing',
#   'first',
#   'time',
#   'since',
#   '1988'],
#  ['white',
#   'house',
#   'backs',
#   'nuclear',
#   'subsidies',
#   'split',
#   'climate',
#   'advocates'],
#  ['trump', 'facebook', 'ban', 'fuels', 'grievances', 'keeping', 'bottled'],
#  ['paypal',
#   'rises',
#   'e',
#   'commerce',
#   'strength',
#   'persists',
#   'vaccine',
#   'era'],
#  ['quite', 'spotty', 'apollo', 'sees', 'lack', 'distress', 'persisting'],
#  ['ramaphosa',
#   'tightens',
#   'grip',
#   'ruling',
#   'party',
#   'sidelines',
#   'main',
#   'rival'],
#  ['google',
#   'relaxes',
#   'work',
#   'from',
#   'home',
#   'rules',
#   'let',
#   'staff',
#   'remote'],
#  ['cathie', 'woods', 'ark', 'battered', 'selloff', 'worst', 'run', 'outflows'],
#  ['peloton', 'tumbles', 'treadmill', 'recall', 'sales', 'halt', 'safety'],
#  ['bezos', 'sells', '2', '5', 'billion', 'amazon', 'signals', 'coming'],
#  ['germany',
#   'targets',
#   'ambitious',
#   '2045',
#   'net',
#   'zero',
#   'emission',
#   'goal'],
#  ['covids',
#   'shockwaves',
#   'took',
#   'poverty',
#   'latin',
#   'america',
#   'new',
#   'nadir'],
#  ['forbes', 'media', 'talks', 'acquired', 'gsv', 'led', 'group'],
#  ['biden', 'says', 'hes', 'open', 'compromise', 'corporate', 'tax', 'hike'],
#  ['trudeaus',
#   'plan',
#   'risks',
#   'exhausting',
#   'fiscal',
#   'cushion',
#   'watchdog',
#   'says'],
#  ['brazilian', 'real', 'extends', 'gains', 'sharp', 'rate', 'hike', 'pledge'],
#  ['uber', 'says', 'costs', 'recruit', 'drivers', 'weigh', 'results'],
#  ['metlife',
#   'private',
#   'equity',
#   'returns',
#   'drive',
#   'quarterly',
#   'profit',
#   'higher'],
#  ['manulife', 'ceo', 'sees', 'lift', 'rate', 'rise', 'short', 'term', 'noise'],
#  ['new',
#   'york',
#   'city',
#   'pitches',
#   'vaccines',
#   'tourism',
#   'benefit',
#   'virus',
#   'update'],
#  ['u',
#   's',
#   'lawmakers',
#   'ask',
#   'bidens',
#   'aid',
#   'vietnamese',
#   'pork',
#   'tariffs'],
#  ['g', '7', 'lists', 'many', 'ways', 'deeply', 'unhappy', 'china'],
#  ['huarongs', 'fate', 'may', 'rest', 'xi', 'confidant', 'loathes', 'bailouts'],
#  ['tumbling',
#   'chinese',
#   'rocket',
#   'expected',
#   're',
#   'enter',
#   'atmosphere',
#   'may',
#   '8'],
#  ['worlds', 'biggest', 'brands', 'adopt', 'checklist', 'rescue', 'seafarers'],
#  ['u', 'k', 'sends', 'navy', 'patrol', 'ships', 'jersey', 'french', 'threats'],
#  ['china',
#   'stocks',
#   'slump',
#   'vaccine',
#   'ip',
#   'waiver',
#   'proposal',
#   'hits',
#   'drugmakers'],
#  ['bezoss',
#   'blue',
#   'origin',
#   'sets',
#   'first',
#   'human',
#   'spaceflight',
#   'july',
#   '20'],
#  ['drugmakers',
#   'warn',
#   'china',
#   'flight',
#   'halt',
#   'india',
#   'could',
#   'snarl',
#   'supplies'],
#  ['dow',
#   'average',
#   'hits',
#   'record',
#   'fridays',
#   'jobs',
#   'data',
#   'markets',
#   'wrap'],
#  ['bloomberg', 'retracts', 'zambia', 'mine', 'story'],
#  ['indias', 'stock', 'market', 'lives', 'another', 'planet'],
#  ['race', 'libors', 'replacement', 'close', 'call'],
#  ['u',
#   's',
#   'back',
#   'waiver',
#   'vaccine',
#   'ip',
#   'protections',
#   'wto',
#   'tai',
#   'says'],
#  ['untold', 'story', 'jeff', 'bezos', 'beat', 'tabloids'],
#  ['canadas', 'vaccine', 'push', 'plagued', 'confusion', 'erratic', 'supply'],
#  ['l',
#   't',
#   'tech',
#   'q4',
#   'review',
#   'demand',
#   'intact',
#   'prabhudas',
#   'lilladher'],
#  ['kotak',
#   'mahindra',
#   'bank',
#   'q4',
#   'another',
#   'quarter',
#   'mixed',
#   'performance',
#   'prabhudas',
#   'lilladher'],
#  ['u',
#   's',
#   'vaccine',
#   'patent',
#   'surprise',
#   'roils',
#   'pharma',
#   'wto',
#   'debate',
#   'heats'],
#  ['sbi',
#   'life',
#   'q4',
#   'review',
#   'strong',
#   'pullback',
#   'momentum',
#   'continue',
#   'prabhudas',
#   'lilladher'],
#  ['sis',
#   'q4',
#   'review',
#   'compelling',
#   'valuations',
#   'rerating',
#   'follow',
#   'growth',
#   'fy22',
#   'motilal',
#   'oswal'],
#  ['shriram',
#   'city',
#   'union',
#   'finance',
#   'stable',
#   'performance',
#   'asset',
#   'quality',
#   'q4',
#   'disbursements',
#   'recover',
#   'motilal',
#   'oswal'],
#  ['rupee', 'bond', 'update', 'may', '04', '2021', 'reliance', 'securities'],
#  ['kotak',
#   'mahindra',
#   'bank',
#   'q4',
#   'review',
#   'track',
#   'despite',
#   'hiccups',
#   'dolat',
#   'capital'],
#  ['sterlite',
#   'technologies',
#   'eyes',
#   'global',
#   'indian',
#   'orders',
#   'boost',
#   'business'],
#  ['sbi',
#   'life',
#   'q4',
#   'review',
#   'business',
#   'growth',
#   'perks',
#   'up',
#   'vnb',
#   'margin',
#   'surprises',
#   'positively',
#   'motilal',
#   'oswal'],
#  ['seven', 'charts', 'show', 'indian', 'economy', 'fared', 'april'],
#  ['powergrid',
#   'invit',
#   'monetisation',
#   'plans',
#   'set',
#   'take',
#   'off',
#   'motilal',
#   'oswal'],
#  ['varun',
#   'beverages',
#   'q1',
#   'review',
#   'strong',
#   'volume',
#   'growth',
#   'demand',
#   'recovery',
#   'motilal',
#   'oswal'],
#  ['kotak',
#   'mahindra',
#   'bank',
#   'q4',
#   'review',
#   'elevated',
#   'provisioning',
#   'weak',
#   'nii',
#   'drive',
#   'earnings',
#   'miss',
#   'motilal',
#   'oswal'],
#  ['consumer',
#   'durables',
#   'sector',
#   'update',
#   'crisis',
#   'peak',
#   'season',
#   'poses',
#   'risk',
#   'air',
#   'conditioner',
#   'offtake',
#   'motilal',
#   'oswal'],
#  ['godrej',
#   'properties',
#   'q4',
#   'review',
#   'strong',
#   'end',
#   'challenging',
#   'year',
#   'icici',
#   'securities'],
#  ['sebi', 'tribunal'],
#  ['fin',
#   'homes',
#   'q4',
#   'review',
#   'sharp',
#   'pick',
#   'up',
#   'disbursements',
#   'yields',
#   'soften',
#   'motilal',
#   'oswal'],
#  ['indias',
#   'economic',
#   'activity',
#   'grows',
#   'double',
#   'digits',
#   'march',
#   'motilal',
#   'oswal'],
#  ['shriram',
#   'city',
#   'union',
#   'finance',
#   'q4',
#   'review',
#   'stability',
#   'demonstrated',
#   'odds',
#   'icici',
#   'securities'],
#  ['data',
#   'preview',
#   'cpi',
#   'inflation',
#   'likely',
#   'ease',
#   'april',
#   'wpi',
#   'increase',
#   'series',
#   'high',
#   '11',
#   'icici',
#   'securities'],
#  ['congo',
#   'president',
#   'declares',
#   'martial',
#   'law',
#   'two',
#   'eastern',
#   'provinces'],
#  ['india',
#   'strategy',
#   'in',
#   'line',
#   'q4',
#   'earnings',
#   'far',
#   'result',
#   'eps',
#   'base',
#   'expansion',
#   'icici',
#   'securities'],
#  ['dalmia',
#   'bharat',
#   'expects',
#   'q1',
#   'volumes',
#   'drop',
#   'sequentially',
#   'fresh',
#   'covid',
#   'lockdowns'],
#  ['mars', 'wrigley', 'getting', 'high', 'medicated', 'skittles', 'joke'],
#  ['supreme',
#   'industries',
#   'another',
#   'quarter',
#   'superlative',
#   'performance',
#   'idbi',
#   'capital'],
#  ['ipl',
#   '2021',
#   'suspended',
#   'midway',
#   'account',
#   'covid',
#   '19',
#   'second',
#   'wave'],
#  ['little',
#   'known',
#   'chinese',
#   'trader',
#   'buys',
#   'new',
#   'york',
#   'sugar',
#   'surprise',
#   'move'],
#  ['sbi',
#   'life',
#   'q4',
#   'review',
#   'business',
#   'gains',
#   'traction',
#   'continue',
#   'ahead',
#   'icici',
#   'direct'],
#  ['l',
#   't',
#   'tech',
#   'q4',
#   'review',
#   'upward',
#   'revisions',
#   'likely',
#   'guidance',
#   'front',
#   'motilal',
#   'oswal'],
#  ['malaysia', 'airlines', 'says', 'travel', 'demand', 'stay', 'weak', '2023'],
#  ['fin',
#   'homes',
#   'q4',
#   'review',
#   'pressure',
#   'margins',
#   'disbursements',
#   'picking',
#   'up',
#   'axis',
#   'securities'],
#  ['castrol',
#   'india',
#   'stronger',
#   'growth',
#   'retail',
#   'outlets',
#   'key',
#   'outlook',
#   'icici',
#   'securities'],
#  ['supreme',
#   'industries',
#   'q4',
#   'review',
#   'strong',
#   'beat',
#   'led',
#   'inventory',
#   'gains',
#   'icici',
#   'securities'],
#  ['varun',
#   'beverages',
#   'q1',
#   'review',
#   'sustained',
#   'volume',
#   'growth',
#   'icici',
#   'securities'],
#  ['l',
#   't',
#   'tech',
#   'q4',
#   'review',
#   'questionable',
#   'multiples',
#   'icici',
#   'securities'],
#  ['sbi',
#   'life',
#   'q4',
#   'review',
#   'strong',
#   'performance',
#   'comfortable',
#   'valuations',
#   'axis',
#   'securities'],
#  ['kotak',
#   'mahindra',
#   'bank',
#   'slippages',
#   'credit',
#   'cost',
#   'elevated',
#   'structurally',
#   'ready',
#   'growth',
#   'icici',
#   'securities'],
#  ['madrid', 'voters', 'reward', 'sanchez', 'rival', 'kept', 'economy', 'open'],
#  ['sensex', 'nifty', 'close', 'lower', 'pharma', 'stocks', 'reliance', 'drag'],
#  ['marico',
#   'expects',
#   'margin',
#   'pressures',
#   'ease',
#   'second',
#   'half',
#   'fy22'],
#  ['italy',
#   'considers',
#   'boosting',
#   'tax',
#   'benefits',
#   'buying',
#   'loss',
#   'making',
#   'banks'],
#  ['cheney', 're', 'ignites', 'fight', 'trump', 'false', 'election', 'claims'],
#  ['supreme',
#   'industries',
#   'volume',
#   'growth',
#   'inventory',
#   'gains',
#   'led',
#   'margin',
#   'expansion',
#   'dolat',
#   'capital'],
#  ['asias', 'hottest', 'stock', 'market', 'vietnam', 'primed', 'inflows'],
#  ['cesc', 'next', 'rerating', 'candidate', 'icici', 'securities'],
#  ['1', '495', 'coffee', 'grinder', 'makes', 'work', 'great', 'brew'],
#  ...]

# %%
from gensim.models import KeyedVectors

glove_model = KeyedVectors.load_word2vec_format('gloves/converted_vectors300.txt', binary=False)

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string
import numpy as np

def get_average_word2vec(tokens_list, vector=glove_model, generate_missing=False, k=300):
    if len(tokens_list) < 1:
        return np.zeros(k)
    
    vectorized = []
    for word in tokens_list:
        if word in vector:
            vectorized.append(vector[word])
        elif generate_missing:
            vectorized.append(np.random.rand(k))
    
    if not vectorized:
        return np.zeros(k)
    
    # Only compute the mean if there are non-zero vectors
    if len(vectorized) > 0:
        return np.mean(vectorized, axis=0)
    else:
        return np.zeros(k)



def get_word2vec_embeddings(vectors, corpus, generate_missing=False):
    embeddings = []
    for title in corpus:
        averaged_embedding = get_average_word2vec(title, vectors, generate_missing=generate_missing)
        embeddings.append(averaged_embedding)
    return embeddings


from sklearn.metrics.pairwise import cosine_similarity

def recommend_news_based_on_keyword(keyword, vectors, data):
    keyword = keyword.split()
    keyword = get_average_word2vec(keyword, vectors)
    
    # Calculate vectors for title
    # cut down the title into lists of words before applying the get_average_word2vec functio
    data['title_vector'] = data['title'].apply(lambda x: get_average_word2vec(x.split(), vectors))
    data['short_desc_vector'] = data['short_description'].apply(lambda x: get_average_word2vec(x.split(), vectors))
    data['desc_vector'] = data['description'].apply(lambda x: get_average_word2vec(x.split(), vectors))

    # Compute cosine similarity for each title vector
    data['title_similarity'] = data.apply(lambda row: cosine_similarity([row['title_vector']], [keyword])[0][0], axis=1)
    data['short_desc_similarity'] = data.apply(lambda row: cosine_similarity([row['short_desc_vector']], [keyword])[0][0], axis=1)
    data['desc_similarity'] = data.apply(lambda row: cosine_similarity([row['desc_vector']], [keyword])[0][0], axis=1)

    # Combine similarities with weights
    title_weight = 0.7
    short_desc_weight = 0.2
    desc_weight = 0.1

    data['combined_similarity'] = (title_weight * data['title_similarity'] +
                                      short_desc_weight * data['short_desc_similarity'] +
                                      desc_weight * data['desc_similarity'])

    # Sort by title similarity
    data = data.sort_values(by='title_similarity', ascending=False)
    
    return data

recommend_news_based_on_keyword('trump', glove_model, data)[:10]
# Out:
#                                                     url  \
# 1180  https://www.bloombergquint.com/markets/kkr-sig...
# 1813  https://www.bloombergquint.com/markets/trump-s...
# 1225  https://www.bloombergquint.com/quicktakes/trum...
# 84    https://www.bloombergquint.com/business/bernie...
# 2019  https://www.bloombergquint.com/gadfly/2020-ele...
# 3239  https://www.bloombergquint.com/business/ex-tru...
# 3888  https://www.bloombergquint.com/politics/trump-...
# 813   https://www.bloombergquint.com/gadfly/trump-fa...
# 2161  https://www.bloombergquint.com/politics/judge-...
# 256   https://www.bloombergquint.com/view/trump-mcca...
#
#                                                   title  \
# 1180  kkr signs lease san francisco tower vornado ow...
# 1813  trump scores 617 million cash vornado tower bonds
# 1225              trump back facebook much rides ruling
# 84                         bernie s back trump may fine
# 2019             republicans still skeptical trump lost
# 3239  ex trump aides cite mlk group lawsuit claiming...
# 3888  trump discussing moving new jersey golf club s...
# 813                trump stays banned facebook keep way
# 2161  judge declines toss amazon suit claiming trump...
# 256              trump mccabe justice department go war
#
#                                       short_description              author  \
# 1180  kkr signs lease san francisco tower vornado ow...        Natalie Wong
# 1813  trump scores 617 million cash vornado tower bonds      Adam Tempkin &
# 1225              trump back facebook much rides ruling     Magan Sherzai,
# 84                         bernie s back trump may fine     Kathleen Hunter
# 2019             republicans still skeptical trump lost   Stephen L. Carter
# 3239  ex trump aides cite mlk suit claiming racism w...         Erik Larson
# 3888  trump discussing relocation new jersey golf cl...     Mark Niquette &
# 813                trump stays banned facebook keep way  Timothy L. O'Brien
# 2161  judge declines toss amazon suit claiming trump...           Naomi Nix
# 256              trump mccabe justice department go war  Timothy L. O'Brien
#
#                    date_created              date_modified        category  \
# 1180  04 May 2021, 10:20 PM IST   05 May 2021, 2:24 PM IST         Markets
# 1813  30 Apr 2021, 11:23 PM IST   03 May 2021, 4:04 AM IST         Markets
# 1225   04 May 2021, 7:34 PM IST  13 May 2021, 12:01 AM IST      QuickTakes
# 84     20 Feb 2019, 4:37 PM IST   20 Feb 2019, 6:33 PM IST        Business
# 2019   28 Apr 2021, 8:00 PM IST   29 Apr 2021, 1:29 AM IST  Opinion/Gadfly
# 3239   27 Apr 2021, 9:38 PM IST   28 Apr 2021, 8:05 AM IST        Business
# 3888  23 Apr 2021, 10:50 PM IST   26 Apr 2021, 2:00 PM IST        Politics
# 813    05 May 2021, 7:48 PM IST   06 May 2021, 1:18 AM IST  Opinion/Gadfly
# 2161   29 Apr 2021, 1:09 AM IST   29 Apr 2021, 4:15 PM IST        Politics
# 256    20 Feb 2019, 5:30 PM IST  21 Feb 2019, 10:45 AM IST    Opinion/View
#
#                                         raw_description  \
# 1180  <div class="story-element story-element-text">...
# 1813  <div class="story-element story-element-text">...
# 1225  <div class="story-element story-element-text">...
# 84    <div class="story-element story-element-text">...
# 2019  <div class="story-element story-element-text">...
# 3239  <div class="story-element story-element-text">...
# 3888  <div class="story-element story-element-text">...
# 813   <div class="story-element story-element-text">...
# 2161  <div class="story-element story-element-text">...
# 256   <div class="story-element story-element-text">...
#
#                                             description  \
# 1180  kkr co renewed lease office space san francisc...
# 1813  investors snapped 1 2 billion bonds linked san...
# 1225  facebook inc s independent oversight board set...
# 84    bloomberg bernie sanders another presidential ...
# 2019  arizona recount votes last novembers president...
# 3239  biden administrations distribution stimulus fu...
# 3888  three months leaving white house mar a lago do...
# 813   donald trump remains banned facebook inc s glo...
# 2161  federal claims court judge wednesday declined ...
# 256   bloomberg opinion andrew mccabe briefly served...
#
#                             publisher          scraped_at  \
# 1180  https://www.bloombergquint.com/ 2021-09-24 00:04:56
# 1813  https://www.bloombergquint.com/ 2021-09-24 00:09:28
# 1225  https://www.bloombergquint.com/ 2021-09-24 00:05:04
# 84    https://www.bloombergquint.com/ 2021-09-24 00:01:42
# 2019  https://www.bloombergquint.com/ 2021-09-24 00:13:00
# 3239  https://www.bloombergquint.com/ 2021-09-24 00:16:44
# 3888  https://www.bloombergquint.com/ 2021-09-24 00:18:33
# 813   https://www.bloombergquint.com/ 2021-09-24 00:03:52
# 2161  https://www.bloombergquint.com/ 2021-09-24 00:13:24
# 256   https://www.bloombergquint.com/ 2021-09-24 00:02:14
#
#                                            title_vector  title_similarity  \
# 1180  [0.021756003, -0.25557932, -0.19321956, 0.0174...          0.496488
# 1813  [-0.2939946, -0.20613238, -0.05099838, 0.07888...          0.480030
# 1225  [-0.017799318, -0.21494932, 0.06627883, 0.0113...          0.478349
# 84    [0.104233, -0.048553657, -0.1589815, 0.0950934...          0.465773
# 2019  [-0.11358621, 0.0332048, 0.14739999, 0.0599292...          0.454702
# 3239  [0.12197861, 0.13917142, -0.10453011, 0.090229...          0.446953
# 3888  [-0.20029823, -0.01796762, 0.19473611, 0.11387...          0.435171
# 813   [-0.028186997, -0.023429334, 0.04559883, 0.057...          0.434464
# 2161  [0.037702758, -0.1254386, 0.0054990053, 0.0250...          0.424410
# 256   [-0.0266887, -0.12927951, 0.045619, 0.05361066...          0.420323
#
#                                       short_desc_vector  \
# 1180  [0.021756003, -0.25557932, -0.19321956, 0.0174...
# 1813  [-0.2939946, -0.20613238, -0.05099838, 0.07888...
# 1225  [-0.017799318, -0.21494932, 0.06627883, 0.0113...
# 84    [0.104233, -0.048553657, -0.1589815, 0.0950934...
# 2019  [-0.11358621, 0.0332048, 0.14739999, 0.0599292...
# 3239  [0.04469566, 0.061023645, -0.0021867817, 0.039...
# 3888  [-0.13968949, -0.031702496, 0.21198237, 0.1013...
# 813   [-0.028186997, -0.023429334, 0.04559883, 0.057...
# 2161  [0.037702758, -0.1254386, 0.0054990053, 0.0250...
# 256   [-0.0266887, -0.12927951, 0.045619, 0.05361066...
#
#                                             desc_vector  \
# 1180  [-0.08587608, -0.068543114, -0.037598625, 0.07...
# 1813  [-0.07671686, 0.034995724, -0.014079804, 0.020...
# 1225  [-0.053342197, 0.025419079, 0.006042888, -0.03...
# 84    [-0.03423882, 0.058100373, 0.014381307, -0.063...
# 2019  [-0.016900886, 0.05901947, 0.05080523, -0.0587...
# 3239  [-0.05176126, 0.003192542, -0.051620755, -0.01...
# 3888  [-0.114298865, 0.04362666, 0.0028919529, 0.028...
# 813   [-0.041263916, 0.037110437, 0.004676091, -0.04...
# 2161  [0.02336615, 0.0250153, -0.0111130215, -0.0627...
# 256   [-0.07048346, -0.051339433, 0.12293914, -0.016...
#
#       short_desc_similarity  desc_similarity  combined_similarity
# 1180               0.496488         0.364957             0.483335
# 1813               0.480030         0.274927             0.459519
# 1225               0.478349         0.200186             0.450533
# 84                 0.465773         0.174135             0.436609
# 2019               0.454702         0.178189             0.427050
# 3239               0.475667         0.160649             0.424066
# 3888               0.461019         0.350792             0.431903
# 813                0.434464         0.206679             0.411685
# 2161               0.424410         0.220090             0.403978
# 256                0.420323         0.239898             0.402281

# %%
from sklearn.metrics.pairwise import cosine_similarity

def recommend_news_based_on_author(author, vectors, data, recent=False):
    author = author.split()
    author = get_average_word2vec(author, vectors)
    
    # Calculate vectors for title
    # cut down the title into lists of words before applying the get_average_word2vec functio
    data['author_vector'] = data['author'].apply(lambda x: get_average_word2vec(x.split(), vectors))

    # Compute cosine similarity for each title vector
    data['author_similarity'] = data.apply(lambda row: cosine_similarity([row['author_vector']], [author])[0][0], axis=1)

    # Sort by title similarity
    data = data.sort_values(by='author_similarity', ascending=False)

    # Sort by date_created if recent is True
    if recent:
        data = data.sort_values(by=['author_similarity', 'date_created'], ascending=[False, False])

    
    return data

recommend_news_based_on_author('matthew monks', glove_model, data, recent=True)[:10]
# Out:
#                                                     url  \
# 2869  https://www.bloombergquint.com/business/stone-...
# 1217  https://www.bloombergquint.com/business/israel...
# 2275  https://www.bloombergquint.com/onweb/blockchai...
# 1978  https://www.bloombergquint.com/markets/alchemy...
# 3350  https://www.bloombergquint.com/business/saudi-...
# 618   https://www.bloombergquint.com/markets/goldman...
# 801   https://www.bloombergquint.com/business/goldma...
# 923   https://www.bloombergquint.com/global-economic...
# 1160  https://www.bloombergquint.com/onweb/kashkari-...
# 797   https://www.bloombergquint.com/business/how-to...
#
#                                                   title  \
# 2869       stone point gic near 3 billion deal ascensus
# 1217  israels lender leumi said weigh sale u s bank arm
# 2275  blockchain firm paxos valued 2 4 billion new f...
# 1978  alchemy funding round values blockchain startu...
# 3350  saudis talks sell aramco stake global energy firm
# 618   goldman offers new bitcoin derivatives wall st...
# 801   goldman sachs leads investment crypto firm coi...
# 923     fed hawks join chorus playing worries inflation
# 1160  kashkari says fed shouldnt cut jobs recovery p...
# 797        agave distillers find success inmexican corn
#
#                                       short_description             author  \
# 2869       stone point gic near 3 billion deal ascensus      matthew monks
# 1217    israels bank leumi said weigh sale u s bank arm      matthew monks
# 2275  blockchain firm paxos valued 2 4 billion new f...    matthew leising
# 1978  alchemy funding round values blockchain startu...    matthew leising
# 3350  saudi crown prince sees unemployment falling v...   matthew martin,
# 618   goldman offers new bitcoin derivatives wall st...    matthew leising
# 801   goldman sachs leads investment crypto firm coi...    matthew leising
# 923   feds evans says risk upward inflation spiral r...  matthew boesler,
# 1160  kashkari says fed shouldnt cut jobs recovery p...    matthew boesler
# 797        agave mexican distillers find success incorn  matthew kronsberg
#
#                    date_created              date_modified          category  \
# 2869   26 Apr 2021, 5:53 AM IST   27 Apr 2021, 1:31 AM IST          Business
# 1217   04 May 2021, 8:22 PM IST   05 May 2021, 8:06 PM IST          Business
# 2275   29 Apr 2021, 3:30 PM IST   29 Apr 2021, 6:00 PM IST             OnWeb
# 1978   28 Apr 2021, 7:45 PM IST   28 Apr 2021, 9:34 PM IST           Markets
# 3350   28 Apr 2021, 2:02 AM IST   29 Apr 2021, 4:51 PM IST          Business
# 618   06 May 2021, 11:48 PM IST   07 May 2021, 4:05 PM IST           Markets
# 801    05 May 2021, 9:01 PM IST  06 May 2021, 12:01 AM IST          Business
# 923    05 May 2021, 7:00 PM IST   06 May 2021, 3:46 PM IST  Global Economics
# 1160   05 May 2021, 5:26 AM IST  05 May 2021, 11:13 AM IST             OnWeb
# 797    05 May 2021, 2:42 PM IST  06 May 2021, 12:09 AM IST          Business
#
#                                         raw_description  \
# 2869  <div class="story-element story-element-text">...
# 1217  <div class="story-element story-element-text">...
# 2275  <div class="story-element story-element-text">...
# 1978  <div class="story-element story-element-text">...
# 3350  <div class="story-element story-element-text">...
# 618   <div class="story-element story-element-text">...
# 801   <div class="story-element story-element-text">...
# 923   <div class="story-element story-element-text">...
# 1160  <div class="story-element story-element-text">...
# 797   <div class="story-element story-element-text">...
#
#                                             description  \
# 2869  stone point capital gic pte agreed buy majorit...
# 1217  bank leumi le israel bm one israels largest le...
# 2275  paxos trust co blockchain startup caters finan...
# 1978  blockchain technology provider alchemy raised ...
# 3350  saudi arabias crown prince said kingdom talks ...
# 618   goldman sachs group inc wading deeper 1 trilli...
# 801   coin metrics cryptocurrency blockchain data pr...
# 923   u s inflation unlikely get control despite unp...
# 1160  federal reserve concerned restoring employment...
# 797   twin pillars mexican gastronomy corn agave hav...
#
#                             publisher          scraped_at  \
# 2869  https://www.bloombergquint.com/ 2021-09-24 00:15:28
# 1217  https://www.bloombergquint.com/ 2021-09-24 00:05:03
# 2275  https://www.bloombergquint.com/ 2021-09-24 00:13:44
# 1978  https://www.bloombergquint.com/ 2021-09-24 00:12:53
# 3350  https://www.bloombergquint.com/ 2021-09-24 00:17:03
# 618   https://www.bloombergquint.com/ 2021-09-24 00:03:19
# 801   https://www.bloombergquint.com/ 2021-09-24 00:03:50
# 923   https://www.bloombergquint.com/ 2021-09-24 00:04:11
# 1160  https://www.bloombergquint.com/ 2021-09-24 00:04:52
# 797   https://www.bloombergquint.com/ 2021-09-24 00:03:49
#
#                                            title_vector  title_similarity  \
# 2869  [-0.30630997, 0.057041995, -0.08096615, 0.0792...          0.160296
# 1217  [0.016921299, -0.1128343, -0.0603186, -0.02621...          0.193678
# 2275  [-0.31685072, 0.049068503, -0.10290613, 0.0653...          0.143901
# 1978  [-0.06986385, 0.06672429, -0.05187643, -0.1289...          0.106687
# 3350  [0.035026878, 0.13490926, -0.1208905, -0.06998...          0.149484
# 618   [-0.1868645, -0.1967425, 0.03986425, -0.039400...          0.140185
# 801   [0.029990122, -0.018193746, -0.041211255, -0.0...          0.151697
# 923   [-0.09801715, 0.13995142, 0.23713319, 0.055956...          0.098371
# 1160  [-0.02255014, 0.06817986, 0.042733572, 0.16993...          0.076245
# 797   [-0.0042649982, 0.402328, 0.070199594, -0.1540...         -0.000188
#
#                                       short_desc_vector  \
# 2869  [-0.30630997, 0.057041995, -0.08096615, 0.0792...
# 1217  [-0.036598712, -0.1505173, -0.0535006, -0.0272...
# 2275  [-0.31685072, 0.049068503, -0.10290613, 0.0653...
# 1978  [-0.06986385, 0.06672429, -0.05187643, -0.1289...
# 3350  [-0.11637555, 0.029903663, 0.11165656, 0.05344...
# 618   [-0.1868645, -0.1967425, 0.03986425, -0.039400...
# 801   [0.029990122, -0.018193746, -0.041211255, -0.0...
# 923   [-0.0010436252, 0.2500946, 0.26179364, 0.16303...
# 1160  [-0.02255014, 0.06817986, 0.042733572, 0.16993...
# 797   [0.155989, 0.619492, 0.0770736, -0.18214199, -...
#
#                                             desc_vector  \
# 2869  [-0.062780924, -0.027941205, 0.036644544, -0.0...
# 1217  [-0.07478223, -0.062382378, 0.0012827241, 0.01...
# 2275  [-0.11201965, -0.012596936, 0.005859773, -0.01...
# 1978  [-0.12346507, 0.02567816, 0.040972196, -0.0496...
# 3350  [-0.0959338, 0.065225884, -0.0028010665, 0.004...
# 618   [-0.13782057, 0.02217669, 0.051817227, -0.0367...
# 801   [-0.13032039, 0.0026853676, 0.040933568, -0.01...
# 923   [-0.05889192, 0.03258123, -0.022422347, 0.0412...
# 1160  [-0.13279803, 0.047807276, -0.015564924, 0.058...
# 797   [-0.10679033, 0.1553635, -0.0032960696, -0.086...
#
#       short_desc_similarity  desc_similarity  combined_similarity  \
# 2869               0.160296         0.167790             0.161046
# 1217               0.167536         0.193487             0.188431
# 2275               0.143901         0.138640             0.143375
# 1978               0.106687         0.140858             0.110104
# 3350               0.089368         0.107475             0.133260
# 618                0.140185         0.145047             0.140671
# 801                0.151697         0.139901             0.150517
# 923                0.023425         0.114605             0.085005
# 1160               0.076245         0.098076             0.078428
# 797                0.006027         0.066734             0.007747
#
#       author_similarity                                      author_vector
# 2869           1.000000  [-0.2817905, -0.35588002, -0.14524001, -0.4551...
# 1217           1.000000  [-0.2817905, -0.35588002, -0.14524001, -0.4551...
# 2275           0.671929  [-0.50133, -0.52345, -0.10044, -0.60057, 0.032...
# 1978           0.671929  [-0.50133, -0.52345, -0.10044, -0.60057, 0.032...
# 3350           0.671929  [-0.50133, -0.52345, -0.10044, -0.60057, 0.032...
# 618            0.671929  [-0.50133, -0.52345, -0.10044, -0.60057, 0.032...
# 801            0.671929  [-0.50133, -0.52345, -0.10044, -0.60057, 0.032...
# 923            0.671929  [-0.50133, -0.52345, -0.10044, -0.60057, 0.032...
# 1160           0.671929  [-0.50133, -0.52345, -0.10044, -0.60057, 0.032...
# 797            0.671929  [-0.50133, -0.52345, -0.10044, -0.60057, 0.032...

# %%
import json

user = json.load(open('data/user.json'))


user_preferences = user['user_preferences']
print(user_preferences)
# Out:
# {'Politics': 4, 'Technology': 3, 'Business': 5, 'Sports': 2, 'Entertainment': 4}

# %%
def recommend_news_based_on_keyword(keyword, vectors, data, user_preferences=None):
    keyword = keyword.split()
    keyword = get_average_word2vec(keyword, vectors)
    
    # Calculate vectors for title
    # cut down the title into lists of words before applying the get_average_word2vec functio
    data['title_vector'] = data['title'].apply(lambda x: get_average_word2vec(x.split(), vectors))
    data['short_desc_vector'] = data['short_description'].apply(lambda x: get_average_word2vec(x.split(), vectors))
    data['desc_vector'] = data['description'].apply(lambda x: get_average_word2vec(x.split(), vectors))

    # Compute cosine similarity for each title vector
    data['title_similarity'] = data.apply(lambda row: cosine_similarity([row['title_vector']], [keyword])[0][0], axis=1)
    data['short_desc_similarity'] = data.apply(lambda row: cosine_similarity([row['short_desc_vector']], [keyword])[0][0], axis=1)
    data['desc_similarity'] = data.apply(lambda row: cosine_similarity([row['desc_vector']], [keyword])[0][0], axis=1)

    # Combine similarities with weights
    title_weight = 0.7
    short_desc_weight = 0.2
    desc_weight = 0.1

    data['combined_similarity'] = (title_weight * data['title_similarity'] +
                                      short_desc_weight * data['short_desc_similarity'] +
                                      desc_weight * data['desc_similarity'])

    # Sort by title similarity
    data = data.sort_values(by='title_similarity', ascending=False)
    
    return data

recommend_news_based_on_keyword('trump', glove_model, data)[:10]
